# %% [markdown]
# ![NTNU logo](https://qore.no/res/ntnu-logo-100.png)
#
#
# # The DL Classifier post processing and reporting tool
#
# ###### Author: Aya Saad
# ###### email: aya.saad@ntnu.no
# ###### Project: AILARON
# ###### Contact
# ###### email: annette.stahl@ntnu.no
# ###### funded by RCN IKTPLUSS program (project number 262701) and supported by NTNU AMOS
# ###### Copyright @NTNU 2020
# ---------------------------------------------------
# <!-- -->

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors as colors
import cmocean
from matplotlib import cm

from matplotlib.ticker import LinearLocator, FormatStrFormatter,PercentFormatter
# %matplotlib inline
#%matplotlib notebook
import os
from datetime import datetime, timedelta
## map plots
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.io.img_tiles as cimgt

# importing library from the SINTEF processing 
# code available at https://github.com/SINTEF/PySilCam
import pysilcam.postprocess as scpp
import pysilcam.plotting as scplt
from pysilcam.config import PySilcamSettings

from scipy import stats as scipystats

# neptus logs library (from Andreas Våge repository)
from dune_proc import load_mission_list
from silcam_proc import *
from plotting_tool import *

# %%
# -*- coding: utf-8 -*-
local_encoding = 'cp850'  # adapt for other encodings
#AirSaturation.csv, Chlorophyll.csv, Conductivity.csv, DissolvedOxygen.csv, EstimatedState.csv, 
# Pressure.csv, Rpm.csv, Salinity.csv, Temperature.csv, Turbidity.csv, WaterDensity.csv,
# WaterVelocity.csv
## Load data from Neptus
neptus_dir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/neptus-logs/20200423/"
mission_list = ["092141_munkholmnAdcp", "095628_munkholmenADCP-square",
               "105605_munkholmenAdcp-square2", "113355_munkholmenAdcp-square3",
               "124406_roald-test-slow-ascend-goto50", "125419_roald-test-slow-ascend-goto60",
               "130848_roald-test-slow-ascend-sk60"]
csv_path = "/mra/csv"
df = load_mission_list(mission_list, neptus_dir, csv_path)
print(df.columns)
# Out:
# Index(['AirSaturation', 'Chlorophyll', 'Conductivity', 'DissolvedOxygen',
#        'lat', 'lon', 'height', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'u', 'v',
#        'w', 'vx', 'vy', 'vz', 'p', 'q', 'r', 'depth', 'alt', 'Pressure', 'Rpm',
#        'Salinity', 'Temperature', 'Turbidity', 'WaterDensity', 'wv_x', 'wv_y',
#        'wv_z'],
#       dtype='object')

# %%
datapath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/20200423config.ini"
roidir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/export"
extdir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext"
SilCamDataPath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/proc/"
SilCamDataFiles = ["RAW-STATS.csv"]
# location of unprocessed silc files
RAWDIR = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/RAW"
RAWBMP = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/RAWBMP"
OUTPUTDIR = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/proc"

# %%
#SilCamDataFile = "F:/resnet_test/proc/RAW-STATS.csv"
#SilCamDataFile2 = "F:/resnet_test/proc02/RAW02-STATS.csv"
#SilCamDataPath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/proc/"
##SilCamDataPath = "F:/resnet_test/proc/"
##SilCamDataFiles = ["RAW-STATS00.csv", "RAW-STATS001.csv"]
#SilCamDataFiles = ["RAW01-STATS.csv","RAW02-STATS.csv","RAW03-STATS.csv"]
##roidir = "F:/resnet_test/export/"
##extdir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext"

# %%
threshold = 0.95
stat = load_silcam_data(SilCamDataFiles, SilCamDataPath)
#stat = stat.dropna()
stat = make_highest_prob(stat)
print('highest prob ', stat.shape)
stat = extract_middle(stat, [75,348, 1700, 2000])
print('stat.shape after extract middle',stat.shape)
#stat = stat[stat['highest prob'] >= threshold]
#stat = stat[stat['probability_copepod'] == stat['highest prob']]
#stat = stat[stat['probability_faecal_pellets'] >= threshold]
#stat = stat[stat['probability_diatom_chain'] == stat['highest prob']]
stat = stat[stat['probability_other'] >= threshold]
stat_comb = stat_grouped(df=stat)
stat_comb = pd.merge_asof(stat_comb, df, on='timestamp', direction='nearest',
                    tolerance=pd.Timedelta('500ms'))
stat_comb = stat_comb.set_index('timestamp',verify_integrity=True)
print(stat.shape)
print(stat_comb.shape)
stat_comb[['file name', 'partind']] = stat_comb['export name'].str.split('-',expand=True) 
print(stat_comb.columns)
stat_comb = stat_comb[(stat_comb['depth']> 1)]
print(stat_comb.shape)
#silc_to_bmp(stat_comb['file name'].tolist(), RAWDIR, RAWBMP)
print(stat_comb['file name'].tolist()[:2])
# Out:
# highest prob  (1492194, 20)
# stat.shape after extract middle (685021, 20)
# (44426, 20)
# (18251, 53)
# Index(['index', 'particle index', 'major_axis_length', 'minor_axis_length',
#        'equivalent_diameter', 'solidity', 'minr', 'minc', 'maxr', 'maxc',
#        'probability_copepod', 'probability_diatom_chain', 'probability_other',
#        'probability_faecal_pellets', 'probability_bubble',
#        'probability_oily_gas', 'probability_oil', 'export name', 'saturation',
#        'highest prob', 'AirSaturation', 'Chlorophyll', 'Conductivity',
#        'DissolvedOxygen', 'lat', 'lon', 'height', 'x', 'y', 'z', 'phi',
#        'theta', 'psi', 'u', 'v', 'w', 'vx', 'vy', 'vz', 'p', 'q', 'r', 'depth',
#        'alt', 'Pressure', 'Rpm', 'Salinity', 'Temperature', 'Turbidity',
#        'WaterDensity', 'wv_x', 'wv_y', 'wv_z', 'file name', 'partind'],
#       dtype='object')
# (15677, 55)
# ['D20200423T092421.075975', 'D20200423T092421.325440']

# %%
print(stat.shape)
stat = stat.dropna()
print(stat.shape)
print(stat_comb.shape)

df_extract = extract_to_roi(stat, stat_comb, roidir, 
                            extdir, 
                            msize=40, minimgsize=1000)
print(df_extract.shape)
if(df_extract.shape[0] > 0):
    objects_to_file(df_extract, roidir, extdir)
else:
    print('Extracted objects are too small!')
# Out:
# (44426, 20)
# (44426, 20)
# (15677, 55)
# inside export_name2im D20200423T092421.075975-PN23
# inside export_name2im D20200423T092421.325440-PN10
# inside export_name2im D20200423T092421.577775-PN3
# inside export_name2im D20200423T092421.827535-PN2
# inside export_name2im D20200423T092422.330400-PN27
# inside export_name2im D20200423T092423.082882-PN25
# inside export_name2im D20200423T092423.834980-PN3
# inside export_name2im D20200423T092424.084194-PN0
# inside export_name2im D20200423T092424.588070-PN29
# inside export_name2im D20200423T092425.091274-PN14
# inside export_name2im D20200423T092425.341345-PN21
# inside export_name2im D20200423T092426.092305-PN33
# inside export_name2im D20200423T092426.593079-PN14
# inside export_name2im D20200423T092427.344345-PN1
# inside export_name2im D20200423T092428.099095-PN0
# inside export_name2im D20200423T092428.852335-PN4
# inside export_name2im D20200423T092429.101107-PN16
# inside export_name2im D20200423T092429.601303-PN31
# inside export_name2im D20200423T092430.356056-PN10
# inside export_name2im D20200423T092430.608504-PN8
# inside export_name2im D20200423T092431.108231-PN20
# inside export_name2im D20200423T092431.356220-PN0
# inside export_name2im D20200423T092431.860400-PN16
# inside export_name2im D20200423T092432.358603-PN14
# inside export_name2im D20200423T092432.609712-PN14
# inside export_name2im D20200423T092432.862772-PN1
# inside export_name2im D20200423T092433.861544-PN19
# inside export_name2im D20200423T092434.110929-PN10
# inside export_name2im D20200423T092434.360991-PN0
# inside export_name2im D20200423T092435.358790-PN7
# inside export_name2im D20200423T092435.610230-PN11
# inside export_name2im D20200423T092435.861116-PN25
# inside export_name2im D20200423T092436.362924-PN0
# inside export_name2im D20200423T092436.863358-PN1
# inside export_name2im D20200423T092437.114925-PN2
# inside export_name2im D20200423T092437.616979-PN20
# inside export_name2im D20200423T092438.366704-PN9
# inside export_name2im D20200423T092438.616697-PN12
# inside export_name2im D20200423T092439.620412-PN11
# inside export_name2im D20200423T092440.123604-PN23
# inside export_name2im D20200423T092440.374271-PN20
# inside export_name2im D20200423T092440.626555-PN3
# inside export_name2im D20200423T092440.876923-PN3
# inside export_name2im D20200423T092441.129092-PN5
# inside export_name2im D20200423T092441.630065-PN0
# inside export_name2im D20200423T092442.381355-PN9
# inside export_name2im D20200423T092442.633176-PN0
# inside export_name2im D20200423T092443.386160-PN2
# inside export_name2im D20200423T092443.634929-PN22
# inside export_name2im D20200423T092444.135231-PN11
# inside export_name2im D20200423T092444.384387-PN1
# inside export_name2im D20200423T092444.633899-PN4
# inside export_name2im D20200423T092444.885443-PN0
# inside export_name2im D20200423T092445.387608-PN2
# inside export_name2im D20200423T092445.638724-PN18
# inside export_name2im D20200423T092445.891044-PN16
# inside export_name2im D20200423T092447.138364-PN23
# inside export_name2im D20200423T092447.642232-PN6
# inside export_name2im D20200423T092448.144332-PN11
# inside export_name2im D20200423T092448.393466-PN29
# inside export_name2im D20200423T092448.645621-PN22
# inside export_name2im D20200423T092448.896147-PN8
# inside export_name2im D20200423T092449.399785-PN23
# inside export_name2im D20200423T092449.651426-PN22
# inside export_name2im D20200423T092449.902002-PN10
# inside export_name2im D20200423T092450.152559-PN6
# inside export_name2im D20200423T092450.652460-PN16
# inside export_name2im D20200423T092450.901475-PN27
# inside export_name2im D20200423T092451.152830-PN12
# inside export_name2im D20200423T092451.403321-PN16
# inside export_name2im D20200423T092451.655679-PN17
# inside export_name2im D20200423T092451.907780-PN28
# inside export_name2im D20200423T092452.156220-PN8
# inside export_name2im D20200423T092452.407366-PN24
# inside export_name2im D20200423T092452.912102-PN4
# inside export_name2im D20200423T092453.415564-PN2
# inside export_name2im D20200423T092453.666125-PN12
# inside export_name2im D20200423T092454.169748-PN30
# inside export_name2im D20200423T092454.673696-PN1
# inside export_name2im D20200423T092454.926125-PN18
# inside export_name2im D20200423T092455.424583-PN35
# inside export_name2im D20200423T092456.425322-PN3
# inside export_name2im D20200423T092457.428146-PN9
# inside export_name2im D20200423T092457.929458-PN16
# inside export_name2im D20200423T092458.179298-PN14
# inside export_name2im D20200423T092458.931481-PN3
# inside export_name2im D20200423T092459.182352-PN1
# inside export_name2im D20200423T092459.433436-PN4
# inside export_name2im D20200423T092459.684242-PN3
# inside export_name2im D20200423T092500.186053-PN8
# inside export_name2im D20200423T092500.688722-PN9
# inside export_name2im D20200423T092500.938170-PN5
# inside export_name2im D20200423T092501.186584-PN21
# inside export_name2im D20200423T092501.437245-PN2
# inside export_name2im D20200423T092501.938094-PN36
# inside export_name2im D20200423T092502.188238-PN16
# inside export_name2im D20200423T092502.692073-PN11
# inside export_name2im D20200423T092502.941343-PN8
# inside export_name2im D20200423T092503.693072-PN16
# inside export_name2im D20200423T092503.944303-PN6
# inside export_name2im D20200423T092504.194978-PN1
# inside export_name2im D20200423T092506.197258-PN14
# inside export_name2im D20200423T092506.446749-PN4
# inside export_name2im D20200423T092506.695188-PN12
# inside export_name2im D20200423T092507.702017-PN3
# inside export_name2im D20200423T092508.204945-PN23
# inside export_name2im D20200423T092508.454232-PN11
# inside export_name2im D20200423T092508.703521-PN0
# inside export_name2im D20200423T092508.954578-PN34
# inside export_name2im D20200423T092509.952290-PN0
# inside export_name2im D20200423T092510.454630-PN47
# inside export_name2im D20200423T092510.953503-PN22
# inside export_name2im D20200423T092511.455929-PN17
# inside export_name2im D20200423T092511.706726-PN10
# inside export_name2im D20200423T092511.955058-PN1
# inside export_name2im D20200423T092513.459252-PN5
# inside export_name2im D20200423T092513.707329-PN0
# inside export_name2im D20200423T092513.957092-PN38
# inside export_name2im D20200423T092514.705592-PN4
# inside export_name2im D20200423T092514.956439-PN11
# inside export_name2im D20200423T092515.458573-PN13
# inside export_name2im D20200423T092515.960783-PN0
# inside export_name2im D20200423T092516.212838-PN8
# inside export_name2im D20200423T092516.714515-PN18
# inside export_name2im D20200423T092516.966801-PN3
# inside export_name2im D20200423T092517.218276-PN5
# inside export_name2im D20200423T092517.970339-PN6
# inside export_name2im D20200423T092518.222113-PN17
# inside export_name2im D20200423T092518.726236-PN0
# inside export_name2im D20200423T092518.977071-PN29
# inside export_name2im D20200423T092519.726655-PN35
# inside export_name2im D20200423T092520.227599-PN18
# inside export_name2im D20200423T092520.477947-PN22
# inside export_name2im D20200423T092520.729518-PN19
# inside export_name2im D20200423T092520.981584-PN18
# inside export_name2im D20200423T092521.231114-PN0
# inside export_name2im D20200423T092521.731506-PN5
# inside export_name2im D20200423T092522.229789-PN13
# inside export_name2im D20200423T092522.478160-PN8
# inside export_name2im D20200423T092523.476095-PN3
# inside export_name2im D20200423T092523.977901-PN33
# inside export_name2im D20200423T092524.230026-PN1
# inside export_name2im D20200423T092524.733978-PN24
# inside export_name2im D20200423T092524.981760-PN12
# inside export_name2im D20200423T092525.231365-PN3
# inside export_name2im D20200423T092525.984915-PN1
# inside export_name2im D20200423T092526.233188-PN25
# inside export_name2im D20200423T092526.486901-PN18
# inside export_name2im D20200423T092526.985881-PN1
# inside export_name2im D20200423T092527.235537-PN14
# inside export_name2im D20200423T092527.485176-PN20
# inside export_name2im D20200423T092528.741824-PN6
# inside export_name2im D20200423T092529.493724-PN17
# inside export_name2im D20200423T092529.742509-PN16
# inside export_name2im D20200423T092530.241309-PN25
# inside export_name2im D20200423T092530.742399-PN10
# inside export_name2im D20200423T092531.745908-PN35
# inside export_name2im D20200423T092532.999321-PN1
# inside export_name2im D20200423T092534.254779-PN2
# inside export_name2im D20200423T092535.260602-PN12
# inside export_name2im D20200423T092535.510792-PN33
# inside export_name2im D20200423T092536.008425-PN19
# inside export_name2im D20200423T092536.260486-PN4
# inside export_name2im D20200423T092536.760969-PN0
# inside export_name2im D20200423T092537.515626-PN3
# inside export_name2im D20200423T092537.766986-PN6
# inside export_name2im D20200423T092538.017009-PN8
# inside export_name2im D20200423T092538.268746-PN1
# inside export_name2im D20200423T092538.517395-PN16
# inside export_name2im D20200423T092538.766891-PN10
# inside export_name2im D20200423T092539.017058-PN15
# inside export_name2im D20200423T092539.268760-PN2
# inside export_name2im D20200423T092539.769629-PN7
# inside export_name2im D20200423T092540.018242-PN16
# inside export_name2im D20200423T092540.267702-PN10
# inside export_name2im D20200423T092540.516301-PN27
# inside export_name2im D20200423T092540.766645-PN4
# inside export_name2im D20200423T092541.017068-PN3
# inside export_name2im D20200423T092541.265931-PN18
# inside export_name2im D20200423T092541.767684-PN5
# inside export_name2im D20200423T092542.016443-PN0
# inside export_name2im D20200423T092542.514516-PN1
# inside export_name2im D20200423T092542.764022-PN36
# inside export_name2im D20200423T092543.015037-PN20
# inside export_name2im D20200423T092544.009988-PN17
# inside export_name2im D20200423T092544.260095-PN4
# inside export_name2im D20200423T092544.508874-PN2
# inside export_name2im D20200423T092545.009562-PN20
# inside export_name2im D20200423T092545.509589-PN5
# inside export_name2im D20200423T092545.761961-PN4
# inside export_name2im D20200423T092546.517011-PN43
# inside export_name2im D20200423T092546.768348-PN1
# inside export_name2im D20200423T092547.268213-PN7
# inside export_name2im D20200423T092547.518655-PN5
# inside export_name2im D20200423T092547.770018-PN13
# inside export_name2im D20200423T092548.273336-PN29
# inside export_name2im D20200423T092548.775211-PN2
# inside export_name2im D20200423T092549.524937-PN30
# inside export_name2im D20200423T092549.774010-PN6
# inside export_name2im D20200423T092550.524101-PN1
# inside export_name2im D20200423T092550.773040-PN3
# inside export_name2im D20200423T092551.273622-PN21
# inside export_name2im D20200423T092551.521959-PN0
# inside export_name2im D20200423T092551.773815-PN0
# inside export_name2im D20200423T092552.275456-PN10
# inside export_name2im D20200423T092552.527609-PN17
# inside export_name2im D20200423T092553.028742-PN9
# inside export_name2im D20200423T092553.279350-PN5
# inside export_name2im D20200423T092553.526393-PN9
# inside export_name2im D20200423T092554.028092-PN21
# inside export_name2im D20200423T092554.529566-PN6
# inside export_name2im D20200423T092555.778573-PN14
# inside export_name2im D20200423T092556.530744-PN6
# inside export_name2im D20200423T092557.279256-PN7
# inside export_name2im D20200423T092557.780761-PN5
# inside export_name2im D20200423T092558.029620-PN14
# inside export_name2im D20200423T092559.028969-PN29
# inside export_name2im D20200423T092559.282156-PN8
# inside export_name2im D20200423T092559.532173-PN3
# inside export_name2im D20200423T092600.030978-PN6
# inside export_name2im D20200423T092600.281629-PN34
# inside export_name2im D20200423T092600.531406-PN2
# inside export_name2im D20200423T092601.032747-PN9
# inside export_name2im D20200423T092601.285123-PN9
# inside export_name2im D20200423T092601.534517-PN8
# inside export_name2im D20200423T092601.783957-PN0
# inside export_name2im D20200423T092602.281348-PN18
# inside export_name2im D20200423T092603.027931-PN5
# inside export_name2im D20200423T092603.529352-PN16
# inside export_name2im D20200423T092603.781074-PN3
# inside export_name2im D20200423T092604.032305-PN16
# inside export_name2im D20200423T092604.280600-PN11
# inside export_name2im D20200423T092604.529764-PN26
# inside export_name2im D20200423T092605.783322-PN10
# inside export_name2im D20200423T092606.285695-PN26
# inside export_name2im D20200423T092607.037263-PN9
# inside export_name2im D20200423T092607.289898-PN1
# inside export_name2im D20200423T092607.538599-PN35
# inside export_name2im D20200423T092607.791318-PN15
# inside export_name2im D20200423T092608.040217-PN3
# inside export_name2im D20200423T092608.291100-PN19
# inside export_name2im D20200423T092608.539964-PN1
# inside export_name2im D20200423T092609.042109-PN33
# inside export_name2im D20200423T092609.544545-PN23
# inside export_name2im D20200423T092609.796527-PN13
# inside export_name2im D20200423T092610.046819-PN19
# inside export_name2im D20200423T092610.296803-PN16
# inside export_name2im D20200423T092610.546273-PN14
# inside export_name2im D20200423T092610.795796-PN27
# inside export_name2im D20200423T092611.044564-PN22
# inside export_name2im D20200423T092611.296797-PN10
# inside export_name2im D20200423T092611.796676-PN1
# inside export_name2im D20200423T092612.295156-PN4
# inside export_name2im D20200423T092612.795844-PN8
# inside export_name2im D20200423T092613.044953-PN23
# inside export_name2im D20200423T092613.295447-PN29
# inside export_name2im D20200423T092613.545879-PN37
# inside export_name2im D20200423T092614.548939-PN10
# inside export_name2im D20200423T092614.796729-PN8
# inside export_name2im D20200423T092615.300556-PN1
# inside export_name2im D20200423T092615.802690-PN24
# inside export_name2im D20200423T092616.299673-PN1
# inside export_name2im D20200423T092616.551337-PN7
# inside export_name2im D20200423T092617.298013-PN9
# inside export_name2im D20200423T092617.547750-PN6
# inside export_name2im D20200423T092617.797630-PN14
# inside export_name2im D20200423T092618.048839-PN35
# inside export_name2im D20200423T092618.300989-PN17
# inside export_name2im D20200423T092618.550747-PN3
# inside export_name2im D20200423T092619.300560-PN7
# inside export_name2im D20200423T092620.554654-PN2
# inside export_name2im D20200423T092620.806754-PN2
# inside export_name2im D20200423T092621.057689-PN35
# inside export_name2im D20200423T092622.807188-PN19
# inside export_name2im D20200423T092623.057654-PN21
# inside export_name2im D20200423T092623.559463-PN15
# inside export_name2im D20200423T092624.063005-PN42
# inside export_name2im D20200423T092624.312900-PN8
# inside export_name2im D20200423T092624.565398-PN18
# inside export_name2im D20200423T092625.562250-PN23
# inside export_name2im D20200423T092626.317318-PN1
# inside export_name2im D20200423T092626.821440-PN27
# inside export_name2im D20200423T092627.071592-PN15
# inside export_name2im D20200423T092627.323965-PN32
# inside export_name2im D20200423T092628.072386-PN15
# inside export_name2im D20200423T092628.323859-PN13
# inside export_name2im D20200423T092628.572580-PN3
# inside export_name2im D20200423T092628.822678-PN0
# inside export_name2im D20200423T092629.323503-PN33
# inside export_name2im D20200423T092629.572205-PN33
# inside export_name2im D20200423T092629.822691-PN1
# inside export_name2im D20200423T092630.073425-PN5
# inside export_name2im D20200423T092630.574821-PN17
# inside export_name2im D20200423T092630.822960-PN19
# inside export_name2im D20200423T092631.072192-PN22
# inside export_name2im D20200423T092631.324006-PN6
# inside export_name2im D20200423T092631.574793-PN6
# inside export_name2im D20200423T092631.826622-PN0
# inside export_name2im D20200423T092632.327301-PN12
# inside export_name2im D20200423T092632.577204-PN23
# inside export_name2im D20200423T092632.826429-PN11
# inside export_name2im D20200423T092633.075838-PN7
# inside export_name2im D20200423T092633.573401-PN16
# inside export_name2im D20200423T092633.824942-PN0
# inside export_name2im D20200423T092634.325365-PN3
# inside export_name2im D20200423T092634.823902-PN6
# inside export_name2im D20200423T092635.322891-PN4
# inside export_name2im D20200423T092635.572497-PN8
# inside export_name2im D20200423T092636.819848-PN12
# inside export_name2im D20200423T092637.571603-PN13
# inside export_name2im D20200423T092637.821733-PN26
# inside export_name2im D20200423T092638.070333-PN6
# inside export_name2im D20200423T092638.319112-PN5
# inside export_name2im D20200423T092638.569126-PN4
# inside export_name2im D20200423T092639.566573-PN5
# inside export_name2im D20200423T092639.816475-PN4
# inside export_name2im D20200423T092640.067895-PN8
# inside export_name2im D20200423T092640.316833-PN23
# inside export_name2im D20200423T092641.065463-PN4
# inside export_name2im D20200423T092641.563538-PN15
# inside export_name2im D20200423T092641.813239-PN4
# inside export_name2im D20200423T092642.062297-PN9
# inside export_name2im D20200423T092642.311869-PN4
# inside export_name2im D20200423T092642.560425-PN0
# inside export_name2im D20200423T092642.811416-PN3
# inside export_name2im D20200423T092643.311906-PN30
# inside export_name2im D20200423T092644.309919-PN11
# inside export_name2im D20200423T092644.559601-PN18
# inside export_name2im D20200423T092644.809874-PN15
# inside export_name2im D20200423T092645.059914-PN27
# inside export_name2im D20200423T092646.059571-PN0
# inside export_name2im D20200423T092646.814540-PN0
# inside export_name2im D20200423T092647.314294-PN31
# inside export_name2im D20200423T092648.065483-PN12
# inside export_name2im D20200423T092648.564916-PN21
# inside export_name2im D20200423T092649.069062-PN12
# inside export_name2im D20200423T092649.567316-PN11
# inside export_name2im D20200423T092649.819587-PN10
# inside export_name2im D20200423T092650.567183-PN9
# inside export_name2im D20200423T092651.068667-PN25
# inside export_name2im D20200423T092651.567104-PN9
# inside export_name2im D20200423T092654.320515-PN13
# inside export_name2im D20200423T092654.825145-PN3
# inside export_name2im D20200423T092655.324041-PN3
# inside export_name2im D20200423T092655.823011-PN2
# inside export_name2im D20200423T092656.572861-PN2
# inside export_name2im D20200423T092657.074566-PN10
# inside export_name2im D20200423T092657.324538-PN4
# inside export_name2im D20200423T092657.575611-PN11
# inside export_name2im D20200423T092657.823655-PN0
# inside export_name2im D20200423T092658.073892-PN11
# inside export_name2im D20200423T092658.575692-PN9
# inside export_name2im D20200423T092658.825810-PN10
# inside export_name2im D20200423T092659.077600-PN18
# inside export_name2im D20200423T092659.829383-PN17
# inside export_name2im D20200423T092700.078594-PN24
# inside export_name2im D20200423T092700.576044-PN19
# inside export_name2im D20200423T092700.823773-PN5
# inside export_name2im D20200423T092701.322328-PN13
# inside export_name2im D20200423T092701.571046-PN3
# inside export_name2im D20200423T092701.820002-PN10
# inside export_name2im D20200423T092702.567389-PN4
# inside export_name2im D20200423T092703.317694-PN1
# inside export_name2im D20200423T092703.575642-PN0
# inside export_name2im D20200423T092703.818934-PN2
# inside export_name2im D20200423T092704.070552-PN18
# inside export_name2im D20200423T092704.571578-PN32
# inside export_name2im D20200423T092704.820737-PN4
# inside export_name2im D20200423T092705.322726-PN3
# inside export_name2im D20200423T092705.823822-PN15
# inside export_name2im D20200423T092706.073711-PN23
# inside export_name2im D20200423T092706.321705-PN10
# inside export_name2im D20200423T092706.823760-PN17
# inside export_name2im D20200423T092707.072785-PN10
# inside export_name2im D20200423T092707.320824-PN15
# inside export_name2im D20200423T092707.824618-PN2
# inside export_name2im D20200423T092710.333638-PN9
# inside export_name2im D20200423T092710.834905-PN25
# inside export_name2im D20200423T092711.085175-PN15
# inside export_name2im D20200423T092711.337637-PN21
# inside export_name2im D20200423T092711.589337-PN40
# inside export_name2im D20200423T092711.838054-PN7
# inside export_name2im D20200423T092712.838521-PN28
# inside export_name2im D20200423T092713.843771-PN29
# inside export_name2im D20200423T092714.341289-PN33
# inside export_name2im D20200423T092714.591466-PN0
# inside export_name2im D20200423T092715.092873-PN30
# inside export_name2im D20200423T092715.343173-PN4
# inside export_name2im D20200423T092716.094771-PN0
# inside export_name2im D20200423T092716.845362-PN1
# inside export_name2im D20200423T092717.095295-PN0
# inside export_name2im D20200423T092717.345219-PN25
# inside export_name2im D20200423T092717.845908-PN3
# inside export_name2im D20200423T092718.095503-PN24
# inside export_name2im D20200423T092718.345734-PN24
# inside export_name2im D20200423T092718.594985-PN18
# inside export_name2im D20200423T092718.846883-PN18
# inside export_name2im D20200423T092719.096328-PN0
# inside export_name2im D20200423T092719.348600-PN14
# inside export_name2im D20200423T092719.845876-PN28
# inside export_name2im D20200423T092720.094472-PN8
# inside export_name2im D20200423T092720.346378-PN10
# inside export_name2im D20200423T092720.597168-PN2
# inside export_name2im D20200423T092720.846127-PN4
# inside export_name2im D20200423T092721.094567-PN9
# inside export_name2im D20200423T092722.596344-PN32
# inside export_name2im D20200423T092722.848471-PN33
# inside export_name2im D20200423T092723.846082-PN0
# inside export_name2im D20200423T092724.097292-PN30
# inside export_name2im D20200423T092725.098725-PN19
# inside export_name2im D20200423T092725.348682-PN22
# inside export_name2im D20200423T092726.849355-PN32
# inside export_name2im D20200423T092727.098420-PN27
# inside export_name2im D20200423T092727.596846-PN2
# inside export_name2im D20200423T092728.345737-PN4
# inside export_name2im D20200423T092729.102374-PN0
# inside export_name2im D20200423T092729.351776-PN13
# inside export_name2im D20200423T092729.601829-PN6
# inside export_name2im D20200423T092729.851200-PN7
# inside export_name2im D20200423T092730.846863-PN18
# inside export_name2im D20200423T092731.348792-PN21
# inside export_name2im D20200423T092731.598620-PN0
# inside export_name2im D20200423T092731.848327-PN8
# inside export_name2im D20200423T092732.594357-PN3
# inside export_name2im D20200423T092732.842759-PN17
# inside export_name2im D20200423T092733.094929-PN4
# inside export_name2im D20200423T092733.594630-PN22
# inside export_name2im D20200423T092733.845458-PN0
# inside export_name2im D20200423T092734.094232-PN14
# inside export_name2im D20200423T092734.346604-PN3
# inside export_name2im D20200423T092735.098410-PN7
# inside export_name2im D20200423T092735.600492-PN6
# inside export_name2im D20200423T092735.852579-PN6
# inside export_name2im D20200423T092736.601709-PN5
# inside export_name2im D20200423T092736.853586-PN2
# inside export_name2im D20200423T092737.103628-PN1
# inside export_name2im D20200423T092737.355393-PN12
# inside export_name2im D20200423T092737.853841-PN14
# inside export_name2im D20200423T092738.103923-PN9
# inside export_name2im D20200423T092738.604769-PN2
# inside export_name2im D20200423T092738.855941-PN6
# inside export_name2im D20200423T092740.103784-PN17
# inside export_name2im D20200423T092740.355564-PN13
# inside export_name2im D20200423T092741.107537-PN23
# inside export_name2im D20200423T092741.607626-PN0
# inside export_name2im D20200423T092741.856730-PN41
# inside export_name2im D20200423T092742.859714-PN9
# inside export_name2im D20200423T092743.109324-PN4
# inside export_name2im D20200423T092743.357573-PN6
# inside export_name2im D20200423T092745.107252-PN18
# inside export_name2im D20200423T092745.356427-PN12
# inside export_name2im D20200423T092745.853946-PN34
# inside export_name2im D20200423T092746.103143-PN4
# inside export_name2im D20200423T092746.353292-PN2
# inside export_name2im D20200423T092746.856262-PN21
# inside export_name2im D20200423T092747.359136-PN11
# inside export_name2im D20200423T092747.861986-PN16
# inside export_name2im D20200423T092748.113744-PN5
# inside export_name2im D20200423T092748.362635-PN24
# inside export_name2im D20200423T092748.864530-PN9
# inside export_name2im D20200423T092749.368266-PN16
# inside export_name2im D20200423T092749.617931-PN29
# inside export_name2im D20200423T092749.870525-PN16
# inside export_name2im D20200423T092750.119815-PN31
# inside export_name2im D20200423T092750.369999-PN39
# inside export_name2im D20200423T092750.870160-PN6
# inside export_name2im D20200423T092752.122680-PN10
# inside export_name2im D20200423T092752.872122-PN10
# inside export_name2im D20200423T092753.374244-PN2
# inside export_name2im D20200423T092753.873909-PN18
# inside export_name2im D20200423T092754.874288-PN11
# inside export_name2im D20200423T092755.621147-PN23
# inside export_name2im D20200423T092755.869742-PN0
# inside export_name2im D20200423T092756.121692-PN7
# inside export_name2im D20200423T092756.372897-PN11
# inside export_name2im D20200423T092756.622788-PN2
# inside export_name2im D20200423T092757.124235-PN0
# inside export_name2im D20200423T092757.876742-PN43
# inside export_name2im D20200423T092758.129186-PN5
# inside export_name2im D20200423T092758.379275-PN8
# inside export_name2im D20200423T092758.883579-PN3
# inside export_name2im D20200423T092759.134739-PN6
# inside export_name2im D20200423T092759.635860-PN21
# inside export_name2im D20200423T092759.885736-PN34
# inside export_name2im D20200423T092800.136389-PN7
# inside export_name2im D20200423T092800.888383-PN26
# inside export_name2im D20200423T092802.393728-PN12
# inside export_name2im D20200423T092802.642233-PN0
# inside export_name2im D20200423T092803.145493-PN3
# inside export_name2im D20200423T092803.397372-PN43
# inside export_name2im D20200423T092803.648580-PN21
# inside export_name2im D20200423T092803.898656-PN36
# inside export_name2im D20200423T092804.397909-PN8
# inside export_name2im D20200423T092804.647082-PN11
# inside export_name2im D20200423T092805.150775-PN25
# inside export_name2im D20200423T092805.400773-PN22
# inside export_name2im D20200423T092806.147169-PN7
# inside export_name2im D20200423T092806.395925-PN12
# inside export_name2im D20200423T092806.645704-PN18
# inside export_name2im D20200423T092806.898272-PN10
# inside export_name2im D20200423T092807.147736-PN4
# inside export_name2im D20200423T092807.395930-PN19
# inside export_name2im D20200423T092807.645488-PN5
# inside export_name2im D20200423T092807.894363-PN14
# inside export_name2im D20200423T092808.146088-PN20
# inside export_name2im D20200423T092809.399864-PN15
# inside export_name2im D20200423T092809.650213-PN20
# inside export_name2im D20200423T092809.902098-PN24
# inside export_name2im D20200423T092810.151600-PN18
# inside export_name2im D20200423T092810.650659-PN2
# inside export_name2im D20200423T092811.149306-PN9
# inside export_name2im D20200423T092811.401346-PN14
# inside export_name2im D20200423T092811.902517-PN7
# inside export_name2im D20200423T092812.403616-PN12
# inside export_name2im D20200423T092812.655633-PN23
# inside export_name2im D20200423T092813.155756-PN23
# inside export_name2im D20200423T092813.408368-PN2
# inside export_name2im D20200423T092813.909390-PN2
# inside export_name2im D20200423T092816.409793-PN18
# inside export_name2im D20200423T092816.660125-PN31
# inside export_name2im D20200423T092816.912685-PN2
# inside export_name2im D20200423T092817.161996-PN6
# inside export_name2im D20200423T092817.413727-PN6
# inside export_name2im D20200423T092817.911848-PN2
# inside export_name2im D20200423T092818.913654-PN19
# inside export_name2im D20200423T092819.162721-PN1
# inside export_name2im D20200423T092819.661205-PN1
# inside export_name2im D20200423T092820.160876-PN4
# inside export_name2im D20200423T092820.413222-PN5
# inside export_name2im D20200423T092820.664027-PN4
# inside export_name2im D20200423T092820.913763-PN6
# inside export_name2im D20200423T092821.415097-PN5
# inside export_name2im D20200423T092821.666310-PN11
# inside export_name2im D20200423T092821.917344-PN28
# inside export_name2im D20200423T092822.417919-PN20
# inside export_name2im D20200423T092822.918915-PN27
# inside export_name2im D20200423T092823.919297-PN4
# inside export_name2im D20200423T092824.922395-PN8
# inside export_name2im D20200423T092825.171768-PN25
# inside export_name2im D20200423T092825.421919-PN11
# inside export_name2im D20200423T092826.173885-PN10
# inside export_name2im D20200423T092826.674893-PN31
# inside export_name2im D20200423T092827.174505-PN15
# inside export_name2im D20200423T092827.674955-PN1
# inside export_name2im D20200423T092828.422619-PN28
# inside export_name2im D20200423T092829.169983-PN8
# inside export_name2im D20200423T092829.920913-PN19
# inside export_name2im D20200423T092830.669757-PN24
# inside export_name2im D20200423T092830.918572-PN3
# inside export_name2im D20200423T092831.420178-PN37
# inside export_name2im D20200423T092832.171320-PN8
# inside export_name2im D20200423T092834.424530-PN5
# inside export_name2im D20200423T092834.675875-PN24
# inside export_name2im D20200423T092834.926052-PN0
# inside export_name2im D20200423T092835.174927-PN36
# inside export_name2im D20200423T092835.673702-PN25
# inside export_name2im D20200423T092836.177252-PN18
# inside export_name2im D20200423T092837.183115-PN1
# inside export_name2im D20200423T092837.431768-PN0
# inside export_name2im D20200423T092838.431143-PN0
# inside export_name2im D20200423T092838.681828-PN4
# inside export_name2im D20200423T092839.184612-PN0
# inside export_name2im D20200423T092839.934901-PN23
# inside export_name2im D20200423T092840.186118-PN5
# inside export_name2im D20200423T092840.435212-PN35
# inside export_name2im D20200423T092840.686135-PN8
# inside export_name2im D20200423T092841.186755-PN7
# inside export_name2im D20200423T092841.687639-PN25
# inside export_name2im D20200423T092842.439112-PN12
# inside export_name2im D20200423T092842.690433-PN18
# inside export_name2im D20200423T092842.939160-PN20
# inside export_name2im D20200423T092843.188814-PN22
# inside export_name2im D20200423T092843.937281-PN29
# inside export_name2im D20200423T092844.188681-PN20
# inside export_name2im D20200423T092845.691110-PN32
# inside export_name2im D20200423T092846.192428-PN19
# inside export_name2im D20200423T092846.695200-PN34
# inside export_name2im D20200423T092847.448991-PN16
# inside export_name2im D20200423T092847.699976-PN35
# inside export_name2im D20200423T092848.949307-PN5
# inside export_name2im D20200423T092849.450633-PN9
# inside export_name2im D20200423T092850.451412-PN15
# inside export_name2im D20200423T092850.954202-PN5
# inside export_name2im D20200423T092851.452831-PN0
# inside export_name2im D20200423T092851.702036-PN27
# inside export_name2im D20200423T092851.953175-PN11
# inside export_name2im D20200423T092852.204322-PN30
# inside export_name2im D20200423T092852.456730-PN8
# inside export_name2im D20200423T092852.706768-PN0
# inside export_name2im D20200423T092852.956729-PN2
# inside export_name2im D20200423T092853.205765-PN29
# inside export_name2im D20200423T092853.458507-PN26
# inside export_name2im D20200423T092853.960249-PN4
# inside export_name2im D20200423T092854.209191-PN0
# inside export_name2im D20200423T092854.459796-PN15
# inside export_name2im D20200423T092856.466426-PN6
# inside export_name2im D20200423T092856.967944-PN22
# inside export_name2im D20200423T092857.468384-PN1
# inside export_name2im D20200423T092857.717566-PN33
# inside export_name2im D20200423T092858.469333-PN13
# inside export_name2im D20200423T092858.721432-PN3
# inside export_name2im D20200423T092859.220516-PN25
# inside export_name2im D20200423T092859.718117-PN15
# inside export_name2im D20200423T092859.970231-PN1
# inside export_name2im D20200423T092900.219691-PN5
# inside export_name2im D20200423T092900.721674-PN4
# inside export_name2im D20200423T092900.974246-PN21
# inside export_name2im D20200423T092901.728607-PN11
# inside export_name2im D20200423T092902.480556-PN14
# inside export_name2im D20200423T092903.737394-PN12
# inside export_name2im D20200423T092904.239693-PN11
# inside export_name2im D20200423T092904.489739-PN15
# inside export_name2im D20200423T092904.741738-PN15
# inside export_name2im D20200423T092905.997722-PN7
# inside export_name2im D20200423T092906.250365-PN11
# inside export_name2im D20200423T092907.248948-PN1
# inside export_name2im D20200423T092907.749078-PN5
# inside export_name2im D20200423T092908.000506-PN32
# inside export_name2im D20200423T092909.254905-PN2
# inside export_name2im D20200423T092909.503688-PN3
# inside export_name2im D20200423T092911.251155-PN15
# inside export_name2im D20200423T092911.501248-PN0
# inside export_name2im D20200423T092911.752085-PN2
# inside export_name2im D20200423T092912.002675-PN4
# inside export_name2im D20200423T092912.251852-PN4
# inside export_name2im D20200423T092912.750062-PN27
# inside export_name2im D20200423T092913.500881-PN31
# inside export_name2im D20200423T092913.749751-PN14
# inside export_name2im D20200423T092913.998477-PN14
# inside export_name2im D20200423T092914.501071-PN16
# inside export_name2im D20200423T092915.000569-PN2
# inside export_name2im D20200423T092915.250404-PN13
# inside export_name2im D20200423T092916.500435-PN15
# inside export_name2im D20200423T092916.751943-PN12
# inside export_name2im D20200423T092917.253549-PN2
# inside export_name2im D20200423T092918.251590-PN2
# inside export_name2im D20200423T092919.003530-PN21
# inside export_name2im D20200423T092920.504410-PN1
# inside export_name2im D20200423T092920.754266-PN5
# inside export_name2im D20200423T092921.254674-PN19
# inside export_name2im D20200423T092921.506677-PN29
# inside export_name2im D20200423T092923.009025-PN23
# inside export_name2im D20200423T092924.013616-PN27
# inside export_name2im D20200423T092925.266628-PN4
# inside export_name2im D20200423T092925.517640-PN20
# inside export_name2im D20200423T092926.016979-PN22
# inside export_name2im D20200423T092926.517495-PN16
# inside export_name2im D20200423T092927.022463-PN25
# inside export_name2im D20200423T092927.273534-PN16
# inside export_name2im D20200423T092927.525839-PN7
# inside export_name2im D20200423T092927.775642-PN22
# inside export_name2im D20200423T092928.027488-PN14
# inside export_name2im D20200423T092928.776000-PN1
# inside export_name2im D20200423T092929.025916-PN9
# inside export_name2im D20200423T092929.776762-PN3
# inside export_name2im D20200423T092930.029636-PN5
# inside export_name2im D20200423T092930.278127-PN41
# inside export_name2im D20200423T092931.028981-PN18
# inside export_name2im D20200423T092931.278719-PN3
# inside export_name2im D20200423T092931.529161-PN6
# inside export_name2im D20200423T092932.030313-PN32
# inside export_name2im D20200423T092933.276802-PN5
# inside export_name2im D20200423T092933.775658-PN21
# inside export_name2im D20200423T092934.529086-PN14
# inside export_name2im D20200423T092935.276728-PN2
# inside export_name2im D20200423T092936.780797-PN26
# inside export_name2im D20200423T092937.278937-PN2
# inside export_name2im D20200423T092938.531654-PN38
# inside export_name2im D20200423T092938.783247-PN8
# inside export_name2im D20200423T092939.284067-PN0
# inside export_name2im D20200423T092939.534781-PN24
# inside export_name2im D20200423T092939.783717-PN24
# inside export_name2im D20200423T092940.033092-PN8
# inside export_name2im D20200423T092940.281543-PN3
# inside export_name2im D20200423T092940.534053-PN28
# inside export_name2im D20200423T092940.784879-PN7
# inside export_name2im D20200423T092941.033082-PN27
# inside export_name2im D20200423T092941.782386-PN15
# inside export_name2im D20200423T092942.035100-PN4
# inside export_name2im D20200423T092942.536974-PN2
# inside export_name2im D20200423T092943.285908-PN23
# inside export_name2im D20200423T092944.035239-PN3
# inside export_name2im D20200423T092944.285600-PN30
# inside export_name2im D20200423T092945.035799-PN9
# inside export_name2im D20200423T092946.284443-PN9
# inside export_name2im D20200423T092946.536536-PN15
# inside export_name2im D20200423T092946.788561-PN29
# inside export_name2im D20200423T092947.040641-PN22
# inside export_name2im D20200423T092948.047617-PN22
# inside export_name2im D20200423T092948.797342-PN18
# inside export_name2im D20200423T092949.049259-PN1
# inside export_name2im D20200423T092949.553128-PN4
# inside export_name2im D20200423T092950.054721-PN16
# inside export_name2im D20200423T092950.560042-PN12
# inside export_name2im D20200423T092951.306296-PN23
# inside export_name2im D20200423T092951.807336-PN5
# inside export_name2im D20200423T092952.305532-PN29
# inside export_name2im D20200423T092952.807661-PN23
# inside export_name2im D20200423T092953.059306-PN15
# inside export_name2im D20200423T092953.559979-PN8
# inside export_name2im D20200423T092953.808581-PN0
# inside export_name2im D20200423T092954.310084-PN7
# inside export_name2im D20200423T092954.560349-PN12
# inside export_name2im D20200423T092955.310824-PN6
# inside export_name2im D20200423T092955.562739-PN4
# inside export_name2im D20200423T092955.813557-PN11
# inside export_name2im D20200423T092956.064763-PN0
# inside export_name2im D20200423T092956.563209-PN39
# inside export_name2im D20200423T092956.814272-PN5
# inside export_name2im D20200423T092957.313724-PN2
# inside export_name2im D20200423T092957.563633-PN6
# inside export_name2im D20200423T092957.813524-PN28
# inside export_name2im D20200423T092958.061461-PN12
# inside export_name2im D20200423T092958.564355-PN21
# inside export_name2im D20200423T092958.815136-PN22
# inside export_name2im D20200423T093000.571625-PN25
# inside export_name2im D20200423T093001.573965-PN3
# inside export_name2im D20200423T093001.823581-PN25
# inside export_name2im D20200423T093003.077142-PN25
# inside export_name2im D20200423T093003.578264-PN30
# inside export_name2im D20200423T093003.829442-PN12
# inside export_name2im D20200423T093004.082113-PN25
# inside export_name2im D20200423T093004.330777-PN1
# inside export_name2im D20200423T093004.579850-PN9
# inside export_name2im D20200423T093005.079983-PN11
# inside export_name2im D20200423T093005.834890-PN33
# inside export_name2im D20200423T093006.334196-PN32
# inside export_name2im D20200423T093007.333943-PN8
# inside export_name2im D20200423T093007.586064-PN15
# inside export_name2im D20200423T093007.837988-PN7
# inside export_name2im D20200423T093008.087769-PN3
# inside export_name2im D20200423T093008.834859-PN3
# inside export_name2im D20200423T093009.084932-PN4
# inside export_name2im D20200423T093010.835732-PN13
# inside export_name2im D20200423T093011.584849-PN10
# inside export_name2im D20200423T093012.585740-PN14
# inside export_name2im D20200423T093013.086917-PN20
# inside export_name2im D20200423T093013.587614-PN19
# inside export_name2im D20200423T093014.590411-PN16
# inside export_name2im D20200423T093014.838727-PN6
# inside export_name2im D20200423T093015.088187-PN8
# inside export_name2im D20200423T093015.339831-PN5
# inside export_name2im D20200423T093015.589543-PN3
# inside export_name2im D20200423T093015.839370-PN2
# inside export_name2im D20200423T093016.587074-PN8
# inside export_name2im D20200423T093016.840725-PN5
# inside export_name2im D20200423T093017.588926-PN10
# inside export_name2im D20200423T093018.090374-PN2
# inside export_name2im D20200423T093018.338816-PN7
# inside export_name2im D20200423T093018.840505-PN10
# inside export_name2im D20200423T093019.340072-PN2
# inside export_name2im D20200423T093019.588898-PN17
# inside export_name2im D20200423T093019.841275-PN15
# inside export_name2im D20200423T093020.092866-PN26
# inside export_name2im D20200423T093020.592859-PN11
# inside export_name2im D20200423T093020.841686-PN18
# inside export_name2im D20200423T093021.591704-PN0
# inside export_name2im D20200423T093022.092280-PN5
# inside export_name2im D20200423T093022.343596-PN23
# inside export_name2im D20200423T093022.594539-PN3
# inside export_name2im D20200423T093022.844204-PN28
# inside export_name2im D20200423T093023.594144-PN4
# inside export_name2im D20200423T093023.845074-PN5
# inside export_name2im D20200423T093025.094685-PN0
# inside export_name2im D20200423T093025.344938-PN24
# inside export_name2im D20200423T093025.843310-PN34
# inside export_name2im D20200423T093026.094132-PN3
# inside export_name2im D20200423T093026.342614-PN10
# inside export_name2im D20200423T093026.842584-PN28
# inside export_name2im D20200423T093027.092252-PN1
# inside export_name2im D20200423T093028.846255-PN9
# inside export_name2im D20200423T093029.095208-PN3
# inside export_name2im D20200423T093029.347645-PN0
# inside export_name2im D20200423T093030.102561-PN9
# inside export_name2im D20200423T093030.354361-PN23
# inside export_name2im D20200423T093030.855829-PN22
# inside export_name2im D20200423T093031.605983-PN13
# inside export_name2im D20200423T093031.855281-PN14
# inside export_name2im D20200423T093032.105533-PN5
# inside export_name2im D20200423T093032.355799-PN7
# inside export_name2im D20200423T093033.104626-PN14
# inside export_name2im D20200423T093033.857501-PN7
# inside export_name2im D20200423T093034.354734-PN3
# inside export_name2im D20200423T093035.104135-PN23
# inside export_name2im D20200423T093035.606532-PN9
# inside export_name2im D20200423T093036.861663-PN37
# inside export_name2im D20200423T093037.113485-PN1
# inside export_name2im D20200423T093037.862543-PN10
# inside export_name2im D20200423T093039.114988-PN3
# inside export_name2im D20200423T093039.367082-PN4
# inside export_name2im D20200423T093040.622659-PN9
# inside export_name2im D20200423T093040.871103-PN28
# inside export_name2im D20200423T093041.120035-PN3
# inside export_name2im D20200423T093041.372033-PN18
# inside export_name2im D20200423T093041.624574-PN28
# inside export_name2im D20200423T093042.126815-PN16
# inside export_name2im D20200423T093042.376605-PN23
# inside export_name2im D20200423T093043.129086-PN29
# inside export_name2im D20200423T093043.381453-PN27
# inside export_name2im D20200423T093044.133799-PN21
# inside export_name2im D20200423T093045.636167-PN29
# inside export_name2im D20200423T093046.542247-PN35
# inside export_name2im D20200423T093047.023773-PN8
# inside export_name2im D20200423T093047.272906-PN1
# inside export_name2im D20200423T093047.524968-PN33
# inside export_name2im D20200423T093048.028541-PN1
# inside export_name2im D20200423T093048.277602-PN9
# inside export_name2im D20200423T093049.029245-PN1
# inside export_name2im D20200423T093050.283866-PN3
# inside export_name2im D20200423T093050.536370-PN19
# inside export_name2im D20200423T093051.039801-PN26
# inside export_name2im D20200423T093051.289204-PN11
# inside export_name2im D20200423T093052.291760-PN6
# inside export_name2im D20200423T093052.541929-PN19
# inside export_name2im D20200423T093052.793872-PN20
# inside export_name2im D20200423T093053.795694-PN35
# inside export_name2im D20200423T093054.546447-PN10
# inside export_name2im D20200423T093055.047579-PN22
# inside export_name2im D20200423T093055.296798-PN23
# inside export_name2im D20200423T093056.548977-PN12
# inside export_name2im D20200423T093056.801205-PN10
# inside export_name2im D20200423T093057.052786-PN4
# inside export_name2im D20200423T093057.301334-PN26
# inside export_name2im D20200423T093057.552847-PN29
# inside export_name2im D20200423T093058.553318-PN13
# inside export_name2im D20200423T093058.805539-PN2
# inside export_name2im D20200423T093059.055095-PN0
# inside export_name2im D20200423T093059.304728-PN7
# inside export_name2im D20200423T093059.556689-PN14
# inside export_name2im D20200423T093100.053548-PN7
# inside export_name2im D20200423T093101.307099-PN27
# inside export_name2im D20200423T093101.556626-PN36
# inside export_name2im D20200423T093102.557721-PN3
# inside export_name2im D20200423T093103.058927-PN5
# inside export_name2im D20200423T093103.806171-PN18
# inside export_name2im D20200423T093104.056367-PN10
# inside export_name2im D20200423T093104.309041-PN27
# inside export_name2im D20200423T093104.810610-PN6
# inside export_name2im D20200423T093105.059999-PN4
# inside export_name2im D20200423T093105.564360-PN14
# inside export_name2im D20200423T093106.064526-PN15
# inside export_name2im D20200423T093106.314559-PN28
# inside export_name2im D20200423T093106.566435-PN4
# inside export_name2im D20200423T093106.815184-PN10
# inside export_name2im D20200423T093107.570109-PN3
# inside export_name2im D20200423T093108.324340-PN4
# inside export_name2im D20200423T093109.076807-PN24
# inside export_name2im D20200423T093109.577696-PN14
# inside export_name2im D20200423T093110.077881-PN9
# inside export_name2im D20200423T093111.582152-PN2
# inside export_name2im D20200423T093112.081639-PN0
# inside export_name2im D20200423T093113.082299-PN8
# inside export_name2im D20200423T093113.331922-PN24
# inside export_name2im D20200423T093113.581128-PN2
# inside export_name2im D20200423T093113.832738-PN16
# inside export_name2im D20200423T093114.083588-PN25
# inside export_name2im D20200423T093114.835257-PN13
# inside export_name2im D20200423T093115.084770-PN26
# inside export_name2im D20200423T093115.333740-PN4
# inside export_name2im D20200423T093116.080941-PN15
# inside export_name2im D20200423T093116.835814-PN13
# inside export_name2im D20200423T093117.088415-PN9
# inside export_name2im D20200423T093117.587205-PN1
# inside export_name2im D20200423T093118.089445-PN23
# inside export_name2im D20200423T093118.592105-PN10
# inside export_name2im D20200423T093118.843696-PN2
# inside export_name2im D20200423T093119.341998-PN2
# inside export_name2im D20200423T093120.845953-PN3
# inside export_name2im D20200423T093121.850674-PN1
# inside export_name2im D20200423T093122.099237-PN9
# inside export_name2im D20200423T093122.846310-PN2
# inside export_name2im D20200423T093124.351386-PN1
# inside export_name2im D20200423T093124.850204-PN1
# inside export_name2im D20200423T093126.108019-PN11
# inside export_name2im D20200423T093126.360277-PN15
# inside export_name2im D20200423T093126.609933-PN10
# inside export_name2im D20200423T093126.861949-PN18
# inside export_name2im D20200423T093127.366287-PN23
# inside export_name2im D20200423T093127.617035-PN7
# inside export_name2im D20200423T093127.866205-PN2
# inside export_name2im D20200423T093128.117635-PN25
# inside export_name2im D20200423T093128.368978-PN15
# inside export_name2im D20200423T093128.618173-PN5
# inside export_name2im D20200423T093129.119006-PN33
# inside export_name2im D20200423T093129.371109-PN4
# inside export_name2im D20200423T093129.620071-PN0
# inside export_name2im D20200423T093129.870839-PN4
# inside export_name2im D20200423T093130.371669-PN4
# inside export_name2im D20200423T093131.370793-PN13
# inside export_name2im D20200423T093131.619850-PN26
# inside export_name2im D20200423T093132.620457-PN10
# inside export_name2im D20200423T093132.872727-PN16
# inside export_name2im D20200423T093133.625008-PN23
# inside export_name2im D20200423T093133.874993-PN6
# inside export_name2im D20200423T093134.379140-PN29
# inside export_name2im D20200423T093135.133576-PN2
# inside export_name2im D20200423T093135.632896-PN27
# inside export_name2im D20200423T093136.131435-PN22
# inside export_name2im D20200423T093136.882827-PN11
# inside export_name2im D20200423T093137.385739-PN4
# inside export_name2im D20200423T093137.635832-PN4
# inside export_name2im D20200423T093138.137490-PN20
# inside export_name2im D20200423T093138.389893-PN7
# inside export_name2im D20200423T093139.141793-PN18
# inside export_name2im D20200423T093139.393268-PN25
# inside export_name2im D20200423T093139.641665-PN1
# inside export_name2im D20200423T093139.892170-PN16
# inside export_name2im D20200423T093140.141366-PN9
# inside export_name2im D20200423T093141.145960-PN3
# inside export_name2im D20200423T093141.895469-PN4
# inside export_name2im D20200423T093142.398070-PN0
# inside export_name2im D20200423T093142.648057-PN1
# inside export_name2im D20200423T093142.899947-PN10
# inside export_name2im D20200423T093143.402165-PN5
# inside export_name2im D20200423T093143.651069-PN22
# inside export_name2im D20200423T093143.902532-PN1
# inside export_name2im D20200423T093144.401987-PN22
# inside export_name2im D20200423T093144.903013-PN11
# inside export_name2im D20200423T093145.401355-PN2
# inside export_name2im D20200423T093145.652606-PN1
# inside export_name2im D20200423T093147.408703-PN3
# inside export_name2im D20200423T093147.659836-PN29
# inside export_name2im D20200423T093148.665364-PN5
# inside export_name2im D20200423T093149.666876-PN18
# inside export_name2im D20200423T093150.167182-PN13
# inside export_name2im D20200423T093151.165569-PN22
# inside export_name2im D20200423T093151.917011-PN13
# inside export_name2im D20200423T093152.166646-PN3
# inside export_name2im D20200423T093353.252002-PN25
# inside export_name2im D20200423T093353.753956-PN13
# inside export_name2im D20200423T093354.002814-PN16
# inside export_name2im D20200423T093354.255550-PN32
# inside export_name2im D20200423T093354.757915-PN5
# inside export_name2im D20200423T093355.254961-PN8
# inside export_name2im D20200423T093355.504256-PN28
# inside export_name2im D20200423T093355.754002-PN19
# inside export_name2im D20200423T093356.003517-PN4
# inside export_name2im D20200423T093356.505390-PN13
# inside export_name2im D20200423T093356.754354-PN10
# inside export_name2im D20200423T093357.003504-PN23
# inside export_name2im D20200423T093357.503659-PN26
# inside export_name2im D20200423T093357.756208-PN7
# inside export_name2im D20200423T093358.005927-PN2
# inside export_name2im D20200423T093358.509820-PN21
# inside export_name2im D20200423T093359.262930-PN1
# inside export_name2im D20200423T093359.761730-PN21
# inside export_name2im D20200423T093400.011486-PN1
# inside export_name2im D20200423T093400.261603-PN23
# inside export_name2im D20200423T093400.510880-PN30
# ...
# inside export_name2im D20200423T131606.977329-PN9
# inside export_name2im D20200423T131607.475855-PN1
# inside export_name2im D20200423T131607.724976-PN68
# inside export_name2im D20200423T131607.976875-PN2
# inside export_name2im D20200423T131608.728302-PN9
# inside export_name2im D20200423T131608.977148-PN17
# inside export_name2im D20200423T131609.229015-PN63
# inside export_name2im D20200423T131609.479561-PN8
# inside export_name2im D20200423T131609.729447-PN52
# inside export_name2im D20200423T131609.979710-PN17
# inside export_name2im D20200423T131610.228797-PN52
# inside export_name2im D20200423T131610.480531-PN1
# inside export_name2im D20200423T131610.732963-PN11
# inside export_name2im D20200423T131610.985498-PN5
# inside export_name2im D20200423T131611.235244-PN28
# inside export_name2im D20200423T131611.738025-PN56
# inside export_name2im D20200423T131611.990262-PN15
# inside export_name2im D20200423T131612.242506-PN1
# inside export_name2im D20200423T131612.493742-PN12
# inside export_name2im D20200423T131612.745664-PN13
# inside export_name2im D20200423T131612.997327-PN88
# inside export_name2im D20200423T131613.248331-PN1
# inside export_name2im D20200423T131613.499572-PN7
# inside export_name2im D20200423T131613.747819-PN20
# inside export_name2im D20200423T131613.996429-PN40
# inside export_name2im D20200423T131614.246152-PN11
# inside export_name2im D20200423T131614.498514-PN30
# inside export_name2im D20200423T131614.750813-PN1
# inside export_name2im D20200423T131615.000718-PN63
# inside export_name2im D20200423T131615.251291-PN18
# inside export_name2im D20200423T131615.750597-PN54
# inside export_name2im D20200423T131616.000637-PN6
# inside export_name2im D20200423T131616.498015-PN25
# inside export_name2im D20200423T131616.749824-PN0
# inside export_name2im D20200423T131617.001824-PN27
# inside export_name2im D20200423T131617.253031-PN53
# inside export_name2im D20200423T131618.007290-PN5
# inside export_name2im D20200423T131618.258229-PN1
# inside export_name2im D20200423T131618.510222-PN85
# inside export_name2im D20200423T131618.760519-PN3
# inside export_name2im D20200423T131619.009203-PN14
# inside export_name2im D20200423T131619.259631-PN51
# inside export_name2im D20200423T131619.511611-PN4
# inside export_name2im D20200423T131619.763654-PN14
# inside export_name2im D20200423T131620.013196-PN28
# inside export_name2im D20200423T131620.263686-PN55
# inside export_name2im D20200423T131620.513604-PN2
# inside export_name2im D20200423T131620.763424-PN16
# inside export_name2im D20200423T131621.264561-PN19
# inside export_name2im D20200423T131621.514230-PN28
# inside export_name2im D20200423T131621.764581-PN46
# inside export_name2im D20200423T131622.263176-PN4
# inside export_name2im D20200423T131622.512017-PN49
# inside export_name2im D20200423T131622.762833-PN15
# inside export_name2im D20200423T131623.011601-PN5
# inside export_name2im D20200423T131623.262774-PN3
# inside export_name2im D20200423T131623.763176-PN68
# inside export_name2im D20200423T131624.012697-PN56
# inside export_name2im D20200423T131624.261021-PN6
# inside export_name2im D20200423T131624.512850-PN63
# inside export_name2im D20200423T131624.764736-PN90
# inside export_name2im D20200423T131625.014913-PN65
# inside export_name2im D20200423T131625.263068-PN23
# inside export_name2im D20200423T131625.514488-PN1
# inside export_name2im D20200423T131625.765831-PN12
# inside export_name2im D20200423T131626.018076-PN82
# inside export_name2im D20200423T131626.267453-PN13
# inside export_name2im D20200423T131626.517670-PN59
# inside export_name2im D20200423T131626.768515-PN66
# inside export_name2im D20200423T131627.017413-PN30
# inside export_name2im D20200423T131627.267869-PN41
# inside export_name2im D20200423T131627.768449-PN45
# inside export_name2im D20200423T131628.020431-PN2
# inside export_name2im D20200423T131628.519561-PN19
# inside export_name2im D20200423T131628.770606-PN3
# inside export_name2im D20200423T131629.022874-PN10
# inside export_name2im D20200423T131629.272171-PN25
# inside export_name2im D20200423T131629.525149-PN17
# inside export_name2im D20200423T131629.776735-PN24
# inside export_name2im D20200423T131630.026237-PN48
# inside export_name2im D20200423T131630.275595-PN2
# inside export_name2im D20200423T131630.526115-PN103
# inside export_name2im D20200423T131630.774855-PN73
# inside export_name2im D20200423T131631.023697-PN71
# inside export_name2im D20200423T131631.275318-PN14
# inside export_name2im D20200423T131631.523911-PN16
# inside export_name2im D20200423T131631.774551-PN72
# inside export_name2im D20200423T131632.025452-PN60
# inside export_name2im D20200423T131632.276715-PN5
# inside export_name2im D20200423T131632.526576-PN37
# inside export_name2im D20200423T131633.025098-PN38
# inside export_name2im D20200423T131633.276647-PN6
# inside export_name2im D20200423T131633.529002-PN75
# inside export_name2im D20200423T131633.778158-PN55
# inside export_name2im D20200423T131634.030670-PN39
# inside export_name2im D20200423T131634.279892-PN0
# inside export_name2im D20200423T131634.532223-PN1
# inside export_name2im D20200423T131634.781552-PN11
# inside export_name2im D20200423T131635.031621-PN1
# inside export_name2im D20200423T131635.282447-PN39
# inside export_name2im D20200423T131635.781004-PN51
# inside export_name2im D20200423T131636.033733-PN72
# inside export_name2im D20200423T131636.285478-PN46
# inside export_name2im D20200423T131636.534504-PN10
# inside export_name2im D20200423T131636.786624-PN3
# inside export_name2im D20200423T131637.035462-PN41
# inside export_name2im D20200423T131637.283651-PN25
# inside export_name2im D20200423T131637.533611-PN46
# inside export_name2im D20200423T131637.786293-PN58
# inside export_name2im D20200423T131638.037970-PN3
# inside export_name2im D20200423T131638.288708-PN5
# inside export_name2im D20200423T131638.537754-PN0
# inside export_name2im D20200423T131638.787959-PN57
# inside export_name2im D20200423T131639.039249-PN45
# inside export_name2im D20200423T131639.287709-PN69
# inside export_name2im D20200423T131639.536170-PN70
# inside export_name2im D20200423T131639.787641-PN4
# inside export_name2im D20200423T131640.040224-PN78
# inside export_name2im D20200423T131640.289561-PN26
# inside export_name2im D20200423T131640.539049-PN18
# inside export_name2im D20200423T131640.789810-PN16
# inside export_name2im D20200423T131641.038388-PN112
# inside export_name2im D20200423T131641.290364-PN25
# inside export_name2im D20200423T131641.543037-PN47
# inside export_name2im D20200423T131641.792907-PN17
# inside export_name2im D20200423T131642.045243-PN14
# inside export_name2im D20200423T131642.294978-PN44
# inside export_name2im D20200423T131642.794111-PN62
# inside export_name2im D20200423T131643.046163-PN57
# inside export_name2im D20200423T131643.295621-PN10
# inside export_name2im D20200423T131643.794259-PN56
# inside export_name2im D20200423T131644.043457-PN20
# inside export_name2im D20200423T131644.292588-PN8
# inside export_name2im D20200423T131644.542053-PN14
# inside export_name2im D20200423T131644.791770-PN38
# inside export_name2im D20200423T131645.042524-PN34
# inside export_name2im D20200423T131645.293637-PN49
# inside export_name2im D20200423T131645.543311-PN8
# inside export_name2im D20200423T131645.791553-PN0
# inside export_name2im D20200423T131646.042589-PN2
# inside export_name2im D20200423T131646.294939-PN38
# inside export_name2im D20200423T131646.547101-PN1
# inside export_name2im D20200423T131646.797780-PN16
# inside export_name2im D20200423T131647.048933-PN35
# inside export_name2im D20200423T131647.300598-PN91
# inside export_name2im D20200423T131647.553279-PN2
# inside export_name2im D20200423T131647.803477-PN60
# inside export_name2im D20200423T131648.053012-PN53
# inside export_name2im D20200423T131648.302763-PN43
# inside export_name2im D20200423T131648.552924-PN49
# inside export_name2im D20200423T131648.803253-PN4
# inside export_name2im D20200423T131649.051767-PN0
# inside export_name2im D20200423T131649.303603-PN1
# inside export_name2im D20200423T131649.552476-PN0
# inside export_name2im D20200423T131649.803408-PN5
# inside export_name2im D20200423T131650.055278-PN19
# inside export_name2im D20200423T131650.304045-PN0
# inside export_name2im D20200423T131650.557116-PN1
# inside export_name2im D20200423T131650.807285-PN6
# inside export_name2im D20200423T131651.059631-PN39
# inside export_name2im D20200423T131651.311210-PN79
# inside export_name2im D20200423T131651.619589-PN55
# inside export_name2im D20200423T131651.868427-PN7
# inside export_name2im D20200423T131652.119723-PN0
# inside export_name2im D20200423T131652.370924-PN56
# inside export_name2im D20200423T131652.620060-PN11
# inside export_name2im D20200423T131652.870945-PN2
# inside export_name2im D20200423T131653.371222-PN13
# inside export_name2im D20200423T131653.623632-PN2
# inside export_name2im D20200423T131653.874265-PN1
# inside export_name2im D20200423T131654.125976-PN46
# inside export_name2im D20200423T131654.374850-PN77
# inside export_name2im D20200423T131654.874976-PN0
# inside export_name2im D20200423T131655.127036-PN5
# inside export_name2im D20200423T131655.375672-PN2
# inside export_name2im D20200423T131655.879175-PN68
# inside export_name2im D20200423T131656.131222-PN3
# inside export_name2im D20200423T131656.383472-PN24
# inside export_name2im D20200423T131656.885816-PN75
# inside export_name2im D20200423T131657.138344-PN23
# inside export_name2im D20200423T131657.389190-PN0
# inside export_name2im D20200423T131657.640394-PN12
# inside export_name2im D20200423T131657.892180-PN21
# inside export_name2im D20200423T131658.391159-PN75
# inside export_name2im D20200423T131658.640904-PN92
# inside export_name2im D20200423T131658.891376-PN8
# inside export_name2im D20200423T131659.140811-PN37
# inside export_name2im D20200423T131659.641779-PN2
# inside export_name2im D20200423T131659.891444-PN8
# inside export_name2im D20200423T131700.143772-PN38
# inside export_name2im D20200423T131700.393407-PN24
# inside export_name2im D20200423T131700.643134-PN76
# inside export_name2im D20200423T131700.892667-PN74
# inside export_name2im D20200423T131701.142824-PN74
# inside export_name2im D20200423T131701.392243-PN7
# inside export_name2im D20200423T131701.641682-PN50
# inside export_name2im D20200423T131701.891734-PN11
# inside export_name2im D20200423T131702.143173-PN39
# inside export_name2im D20200423T131702.644480-PN8
# inside export_name2im D20200423T131702.896746-PN7
# inside export_name2im D20200423T131703.148791-PN75
# inside export_name2im D20200423T131703.650900-PN31
# inside export_name2im D20200423T131704.153504-PN44
# inside export_name2im D20200423T131704.402978-PN42
# inside export_name2im D20200423T131704.655239-PN56
# inside export_name2im D20200423T131704.904234-PN85
# inside export_name2im D20200423T131705.155986-PN31
# inside export_name2im D20200423T131705.655716-PN32
# inside export_name2im D20200423T131705.906644-PN4
# inside export_name2im D20200423T131706.659938-PN31
# inside export_name2im D20200423T131706.910686-PN53
# inside export_name2im D20200423T131707.162670-PN2
# inside export_name2im D20200423T131707.413213-PN54
# inside export_name2im D20200423T131707.663872-PN15
# inside export_name2im D20200423T131707.913203-PN43
# inside export_name2im D20200423T131708.164139-PN12
# inside export_name2im D20200423T131708.412980-PN36
# inside export_name2im D20200423T131708.665466-PN2
# inside export_name2im D20200423T131709.416471-PN2
# inside export_name2im D20200423T131709.665711-PN7
# inside export_name2im D20200423T131710.164010-PN54
# inside export_name2im D20200423T131710.413233-PN61
# inside export_name2im D20200423T131711.171617-PN2
# inside export_name2im D20200423T131711.429321-PN9
# inside export_name2im D20200423T131712.184176-PN3
# inside export_name2im D20200423T131712.435133-PN6
# inside export_name2im D20200423T131712.936275-PN30
# inside export_name2im D20200423T131713.438922-PN6
# inside export_name2im D20200423T131713.688861-PN3
# inside export_name2im D20200423T131713.940470-PN29
# inside export_name2im D20200423T131714.192442-PN4
# inside export_name2im D20200423T131714.440787-PN22
# inside export_name2im D20200423T131714.688714-PN24
# inside export_name2im D20200423T131715.192997-PN3
# inside export_name2im D20200423T131715.442447-PN5
# inside export_name2im D20200423T131715.694069-PN13
# inside export_name2im D20200423T131716.192729-PN15
# inside export_name2im D20200423T131716.444174-PN4
# inside export_name2im D20200423T131717.196459-PN1
# inside export_name2im D20200423T131717.449286-PN4
# inside export_name2im D20200423T131718.197565-PN13
# inside export_name2im D20200423T131719.198651-PN4
# inside export_name2im D20200423T131719.448454-PN21
# inside export_name2im D20200423T131719.946092-PN17
# inside export_name2im D20200423T131720.446730-PN28
# inside export_name2im D20200423T131720.697522-PN1
# inside export_name2im D20200423T131720.949697-PN17
# inside export_name2im D20200423T131721.199560-PN40
# inside export_name2im D20200423T131721.702796-PN20
# inside export_name2im D20200423T131721.951779-PN6
# inside export_name2im D20200423T131722.707834-PN26
# inside export_name2im D20200423T131723.207556-PN1
# inside export_name2im D20200423T131724.210494-PN0
# inside export_name2im D20200423T131724.460073-PN11
# inside export_name2im D20200423T131725.461847-PN3
# inside export_name2im D20200423T131725.963468-PN5
# inside export_name2im D20200423T131726.463652-PN5
# inside export_name2im D20200423T131726.713174-PN12
# inside export_name2im D20200423T131726.963898-PN17
# inside export_name2im D20200423T131727.466035-PN9
# inside export_name2im D20200423T131727.967854-PN6
# inside export_name2im D20200423T131728.216175-PN20
# inside export_name2im D20200423T131729.972364-PN4
# inside export_name2im D20200423T131730.222592-PN29
# inside export_name2im D20200423T131730.473506-PN7
# inside export_name2im D20200423T131730.723115-PN2
# inside export_name2im D20200423T131730.975278-PN4
# inside export_name2im D20200423T131731.476925-PN10
# inside export_name2im D20200423T131731.977389-PN6
# (10, 20)
# inside export_name2im D20200423T101730.576982-PN3
# inside export_name2im D20200423T101730.576982-PN27
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext\D20200423T101730.576982-PN27.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200423T103325.895087-PN7
# inside export_name2im D20200423T103325.895087-PN10
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext\D20200423T103325.895087-PN10.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200423T103325.895087-PN22
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext\D20200423T103325.895087-PN22.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200423T103655.149975-PN2
# inside export_name2im D20200423T103655.149975-PN26
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext\D20200423T103655.149975-PN26.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200423T103655.149975-PN52
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext\D20200423T103655.149975-PN52.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200423T103655.149975-PN54
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext\D20200423T103655.149975-PN54.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200423T103655.149975-PN62
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext\D20200423T103655.149975-PN62.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# export completed!

# %%
print(df_extract.shape)
scenes = []
for f in df_extract['export name'].tolist():
    n = f.split('-')[0]
    if n not in scenes: 
        scenes.append(n)
print(len(scenes))
#silc_to_bmp(scenes, RAWDIR, RAWBMP)
print(df_extract)
# Out:
# (10, 20)
# 3
#                              index  particle index  major_axis_length  \
# timestamp
# 2020-04-23 10:17:30.576982  433974               3          39.865867
# 2020-04-23 10:17:30.576982  433998              27           5.813989
# 2020-04-23 10:33:25.895087  640941               7          44.168734
# 2020-04-23 10:33:25.895087  640944              10           6.433997
# 2020-04-23 10:33:25.895087  640956              22           5.962858
# 2020-04-23 10:36:55.149975  683131               2          41.695423
# 2020-04-23 10:36:55.149975  683155              26           9.686582
# 2020-04-23 10:36:55.149975  683181              52           7.989160
# 2020-04-23 10:36:55.149975  683183              54          10.008835
# 2020-04-23 10:36:55.149975  683191              62          10.386575
#
#                             minor_axis_length  equivalent_diameter  solidity  \
# timestamp
# 2020-04-23 10:17:30.576982          15.831314            24.253591  0.776471
# 2020-04-23 10:17:30.576982           4.341804             4.918491  0.950000
# 2020-04-23 10:33:25.895087          18.289343            27.982893  0.857741
# 2020-04-23 10:33:25.895087           2.459295             3.908820  0.923077
# 2020-04-23 10:33:25.895087           3.718657             4.652426  0.944444
# 2020-04-23 10:36:55.149975          19.120369            27.268515  0.804408
# 2020-04-23 10:36:55.149975           6.295518             7.225152  0.759259
# 2020-04-23 10:36:55.149975           3.439134             4.787307  0.750000
# 2020-04-23 10:36:55.149975           5.135562             6.863663  0.822222
# 2020-04-23 10:36:55.149975           4.379355             6.482045  0.825000
#
#                               minr    minc    maxr    maxc  \
# timestamp
# 2020-04-23 10:17:30.576982   377.0  1975.0   395.0  2017.0
# 2020-04-23 10:17:30.576982   991.0  1832.0   997.0  1837.0
# 2020-04-23 10:33:25.895087   309.0   371.0   331.0   415.0
# 2020-04-23 10:33:25.895087   342.0  1989.0   346.0  1995.0
# 2020-04-23 10:33:25.895087   621.0   557.0   626.0   562.0
# 2020-04-23 10:36:55.149975   199.0  1985.0   240.0  2009.0
# 2020-04-23 10:36:55.149975   867.0  1949.0   878.0  1957.0
# 2020-04-23 10:36:55.149975  1333.0  1769.0  1341.0  1773.0
# 2020-04-23 10:36:55.149975  1361.0   454.0  1370.0   460.0
# 2020-04-23 10:36:55.149975  1677.0  1942.0  1688.0  1947.0
#
#                             probability_copepod  probability_diatom_chain  \
# timestamp
# 2020-04-23 10:17:30.576982         6.432425e-06                  0.013197
# 2020-04-23 10:17:30.576982         6.143663e-06                  0.008332
# 2020-04-23 10:33:25.895087         4.307178e-08                  0.000468
# 2020-04-23 10:33:25.895087         7.398621e-10                  0.020307
# 2020-04-23 10:33:25.895087         1.801468e-06                  0.032283
# 2020-04-23 10:36:55.149975         2.402153e-07                  0.000255
# 2020-04-23 10:36:55.149975         2.531163e-05                  0.025450
# 2020-04-23 10:36:55.149975         1.122032e-06                  0.004146
# 2020-04-23 10:36:55.149975         6.402151e-06                  0.021193
# 2020-04-23 10:36:55.149975         1.011666e-06                  0.026785
#
#                             probability_other  probability_faecal_pellets  \
# timestamp
# 2020-04-23 10:17:30.576982           0.968741                    0.013721
# 2020-04-23 10:17:30.576982           0.980339                    0.000529
# 2020-04-23 10:33:25.895087           0.998138                    0.000356
# 2020-04-23 10:33:25.895087           0.969878                    0.000009
# 2020-04-23 10:33:25.895087           0.966544                    0.000486
# 2020-04-23 10:36:55.149975           0.988253                    0.003749
# 2020-04-23 10:36:55.149975           0.962615                    0.002875
# 2020-04-23 10:36:55.149975           0.987151                    0.004733
# 2020-04-23 10:36:55.149975           0.975790                    0.000754
# 2020-04-23 10:36:55.149975           0.964000                    0.008133
#
#                             probability_bubble  probability_oily_gas  \
# timestamp
# 2020-04-23 10:17:30.576982        7.173880e-05              0.003869
# 2020-04-23 10:17:30.576982        1.960572e-05              0.010771
# 2020-04-23 10:33:25.895087        2.914330e-06              0.001034
# 2020-04-23 10:33:25.895087        9.308565e-09              0.009805
# 2020-04-23 10:33:25.895087        7.030756e-06              0.000676
# 2020-04-23 10:36:55.149975        1.349351e-05              0.007718
# 2020-04-23 10:36:55.149975        1.364875e-04              0.008835
# 2020-04-23 10:36:55.149975        5.945836e-06              0.003960
# 2020-04-23 10:36:55.149975        2.686030e-05              0.002226
# 2020-04-23 10:36:55.149975        7.820075e-06              0.001072
#
#                             probability_oil                   export name  \
# timestamp
# 2020-04-23 10:17:30.576982     3.926899e-04   D20200423T101730.576982-PN3
# 2020-04-23 10:17:30.576982     3.502397e-06  D20200423T101730.576982-PN27
# 2020-04-23 10:33:25.895087     2.742609e-07   D20200423T103325.895087-PN7
# 2020-04-23 10:33:25.895087     5.413966e-11  D20200423T103325.895087-PN10
# 2020-04-23 10:33:25.895087     1.889767e-06  D20200423T103325.895087-PN22
# 2020-04-23 10:36:55.149975     1.027722e-05   D20200423T103655.149975-PN2
# 2020-04-23 10:36:55.149975     6.373510e-05  D20200423T103655.149975-PN26
# 2020-04-23 10:36:55.149975     2.233894e-06  D20200423T103655.149975-PN52
# 2020-04-23 10:36:55.149975     5.502062e-06  D20200423T103655.149975-PN54
# 2020-04-23 10:36:55.149975     1.403432e-06  D20200423T103655.149975-PN62
#
#                             saturation  highest prob
# timestamp
# 2020-04-23 10:17:30.576982    0.221585      0.968741
# 2020-04-23 10:17:30.576982    0.221585      0.980339
# 2020-04-23 10:33:25.895087    0.239917      0.998138
# 2020-04-23 10:33:25.895087    0.239917      0.969878
# 2020-04-23 10:33:25.895087    0.239917      0.966544
# 2020-04-23 10:36:55.149975    0.263032      0.988253
# 2020-04-23 10:36:55.149975    0.263032      0.962615
# 2020-04-23 10:36:55.149975    0.263032      0.987151
# 2020-04-23 10:36:55.149975    0.263032      0.975790
# 2020-04-23 10:36:55.149975    0.263032      0.964000

# %%
RAWSPEEDBMP = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/RawSpeeds"
speed_int = [1000, 1100]
new_stat = get_raw_speed(stat_comb, speed_int, RAWDIR, RAWSPEEDBMP)

if len(new_stat) > 0:
    silc_to_bmp(new_stat['file name'].tolist(), RAWDIR, RAWSPEEDBMP + str(speed_int[0]) + '_' + str(speed_int[1]))
    new_stat.to_csv(RAWSPEEDBMP + str(speed_int[0]) + '_' + str(speed_int[1]) 
                    + '/'
                    + 'RAWSPEEDBMP' + str(speed_int[0]) + '_' + str(speed_int[1]) + '.csv'
                    , index = False, header=True)
else: 
    print('couldn\'t find images for Rpm between {0} and {1}'.format(str(speed_int[0]), str(speed_int[1])))
# Out:
# Creation of the directory F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/RawSpeeds1000_1100 failed
# conversion completed!

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
mp = ax.scatter3D(df['lon'],df['lat'],df['depth'], c=df['WaterDensity'], cmap=cmocean.cm.dense) # ,norm = colors.LogNorm()
ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
ax.set_xlabel('longitude', fontsize=12, labelpad=-15)
ax.set_ylabel('latitude', fontsize=12, labelpad=-13)
ax.zaxis.set_rotate_label(False) 
x_lab_pos, y_lab_pos = ax.zaxis.label.get_position()
print('x_lab_pos', x_lab_pos, 'y_lab_pos', y_lab_pos)
ax.zaxis._autolabelpos=False
ax.zaxis.label.set_position([x_lab_pos,-10])
#ax.set_zlabel('Depth (meter)', rotation=100, fontsize=12)
#ax.set_zlabel('Depth (meter)', rotation=96, fontsize=10)
ax.set_zlabel('Depth (meter)', rotation=95, fontsize=12)
ax.set_zlabel('Depth (meter)', fontsize=10)
ax.dist = 0
cb = fig.colorbar(mp)

cb.ax.set_ylabel('Density (kg/m\u00b3)', fontsize=14)

print(df['WaterDensity'].min(), df['WaterDensity'].max())
cb.ax.get_yaxis().set_ticks(np.arange(int(df['WaterDensity'].min()), 
                                      int(df['WaterDensity'].max()+1), step=2))
cb.ax.invert_yaxis()
ax.xaxis._axinfo["grid"].update({"linewidth":0.2, "color" : "#D3D3D3"})
ax.yaxis._axinfo["grid"].update({"linewidth":0.2, "color" : "#D3D3D3"})
ax.zaxis._axinfo["grid"].update({"linewidth":0.2, "color" : "#D3D3D3"})
#ax.view_init(75, 269)
#ax.view_init(60, 260)
#ax.view_init(50, 260)
ax.view_init(30, 30)
plt.gca().invert_zaxis() 
plt.show()
# Out:
# x_lab_pos 0.5 y_lab_pos 0
# 1010.673 1026.363

# %%
# -*- coding : utf-8 -*-
local_encoding = 'cp850'  # adapt for other encodings
### SALINITY 
fig = plt.figure(figsize=(7,7))
request = cimgt.StamenTerrain()
ax = plt.subplot(111, projection=request.crs)
plt.sca(ax) 
mp = map_plot(df, request, 'Salinity', cmocean.cm.haline)
cb = fig.colorbar(mp)
cb.ax.set_ylabel('Practical Salinity Unit (PSU)', fontsize=20)
plt.show()
fig.savefig(OUTPUTDIR + '/' + 'mapplot_salinity.eps', bbox_inches='tight')

### TEMPERATURE
fig = plt.figure(figsize=(7,7))
request = cimgt.StamenTerrain()
ax = plt.subplot(111, projection=request.crs)
plt.sca(ax)
mp = map_plot(df, request, 'Temperature', cmocean.cm.ice_r)
cb = fig.colorbar(mp)
cb.ax.set_ylabel('Temperature (\xb0C)', fontsize=20)
plt.show()
fig.savefig(OUTPUTDIR + '/' + 'mapplot_temperature.eps', bbox_inches='tight')

### DENSITY
fig = plt.figure(figsize=(7,7))
request = cimgt.StamenTerrain()
ax = plt.subplot(111, projection=request.crs)
plt.sca(ax) 
mp = map_plot(df, request, 'WaterDensity', cmocean.cm.dense)
cb = fig.colorbar(mp)
cb.ax.set_ylabel('kg/m\u00b3', fontsize=20)
plt.show()
fig.savefig(OUTPUTDIR + '/' + 'mapplot_density.eps', bbox_inches='tight')
