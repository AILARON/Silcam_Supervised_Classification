# %% [markdown]
# ![NTNU logo](https://qore.no/res/ntnu-logo-100.png)
#
#
# # The DL Classifier post processing and reporting tool
#
# ###### Author: Aya Saad
# ###### email: aya.saad@ntnu.no
# ###### Project: AILARON
# ###### Contact
# ###### email: annette.stahl@ntnu.no
# ###### funded by RCN IKTPLUSS program (project number 262701) and supported by NTNU AMOS
# ###### Copyright @NTNU 2020
# ---------------------------------------------------
# <!-- -->

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors as colors
import cmocean
from matplotlib import cm

from matplotlib.ticker import LinearLocator, FormatStrFormatter,PercentFormatter
# %matplotlib inline
#%matplotlib notebook
import os
from datetime import datetime, timedelta
## map plots
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.io.img_tiles as cimgt

# importing library from the SINTEF processing 
# code available at https://github.com/SINTEF/PySilCam
import pysilcam.postprocess as scpp
import pysilcam.plotting as scplt
from pysilcam.config import PySilcamSettings

from scipy import stats as scipystats

# neptus logs library (from Andreas Våge repository)
from dune_proc import * #load_mission_list
from silcam_proc import *
from plotting_tool import *

# %%
# -*- coding: utf-8 -*-
local_encoding = 'cp850'  # adapt for other encodings
#AirSaturation.csv, Chlorophyll.csv, Conductivity.csv, DissolvedOxygen.csv, EstimatedState.csv, 
# Pressure.csv, Rpm.csv, Salinity.csv, Temperature.csv, Turbidity.csv, WaterDensity.csv,
# WaterVelocity.csv
## Load data from Neptus
#neptus_dir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/neptus-logs/20200423/"
#neptus_dir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/neptus-logs/merged_logs/"
#neptus_dir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-21/neptus-merged-logs/"
neptus_dir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/neptus-merged/"
#mission_list = ["092141_munkholmnAdcp", "095628_munkholmenADCP-square",
#               "105605_munkholmenAdcp-square2", "113355_munkholmenAdcp-square3",
#               "124406_roald-test-slow-ascend-goto50", "125419_roald-test-slow-ascend-goto60",
#               "130848_roald-test-slow-ascend-sk60"]
mission_list = [""]
csv_path = "/mra/csv"
df = load_mission_list(mission_list, neptus_dir, csv_path)
#logdir = Path(neptus_dir + csv_path)
#df, units = load_neptus_csvs(logdir)
print(df.columns)
# Out:
# M:\Documents\GitHub\Silcam_Supervised_Classification\reporting_tools\dune_proc.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['lon (rad)'] = df['lon (rad)'] * (180 / np.pi)
# M:\Documents\GitHub\Silcam_Supervised_Classification\reporting_tools\dune_proc.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['lat (rad)'] = df['lat (rad)'] * (180 / np.pi)
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# Index(['AirSaturation', 'Chlorophyll', 'Conductivity', 'DissolvedOxygen',
#        'lat', 'lon', 'height', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'u', 'v',
#        'w', 'vx', 'vy', 'vz', 'p', 'q', 'r', 'depth', 'alt', 'Pressure', 'Rpm',
#        'Salinity', 'Temperature', 'Turbidity', 'WaterDensity', 'wv_x', 'wv_y',
#        'wv_z'],
#       dtype='object')

# %%
datapath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/20200423config.ini"
roidir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/export"
extdir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext"
SilCamDataPath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/proc/"
SilCamDataFiles = ["RAW-STATS.csv"]
# location of unprocessed silc files
RAWDIR = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/RAW"
RAWBMP = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/RAWBMP"
OUTPUTDIR = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/proc"
#### April 21st 2020 
datapath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-21/20200421config.ini"
roidir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-21/export"
extdir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-21/ext"
SilCamDataPath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-21/proc/"
SilCamDataFiles = ["RAW-STATS.csv"]
# location of unprocessed silc files
RAWDIR = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-21/RAW"
RAWBMP = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-21/RAWBMP"
OUTPUTDIR = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-21/proc"
#### April 20th 2020 
datapath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/20200420config.ini"
roidir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/export"
extdir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/ext"
SilCamDataPath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/proc/"
SilCamDataFiles = ["RAW-STATS.csv"]
# location of unprocessed silc files
RAWDIR = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/RAW"
RAWBMP = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/RAWBMP"
OUTPUTDIR = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/proc"

# %%
#SilCamDataFile = "F:/resnet_test/proc/RAW-STATS.csv"
#SilCamDataFile2 = "F:/resnet_test/proc02/RAW02-STATS.csv"
#SilCamDataPath = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/proc/"
##SilCamDataPath = "F:/resnet_test/proc/"
##SilCamDataFiles = ["RAW-STATS00.csv", "RAW-STATS001.csv"]
#SilCamDataFiles = ["RAW01-STATS.csv","RAW02-STATS.csv","RAW03-STATS.csv"]
##roidir = "F:/resnet_test/export/"
##extdir = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/ext"

# %%
threshold = 0.95
stat = load_silcam_data(SilCamDataFiles, SilCamDataPath)
#stat = stat.dropna()
stat = make_highest_prob(stat)
print('highest prob ', stat.shape)
stat = extract_middle(stat, [75,348, 1700, 2000])
print('stat.shape after extract middle',stat.shape)
print('stat.head', stat.head(3))
#stat = stat[stat['highest prob'] >= threshold]
#stat = stat[stat['probability_copepod'] == stat['highest prob']]
#stat = stat[stat['probability_faecal_pellets'] >= threshold]
#stat = stat[stat['probability_diatom_chain'] == stat['highest prob']]
stat = stat[stat['probability_other'] >= threshold]
stat_comb = stat_grouped(df=stat)
stat_comb = pd.merge_asof(stat_comb, df, on='timestamp', direction='nearest',
                    tolerance=pd.Timedelta('500ms'))
stat_comb = stat_comb.set_index('timestamp',verify_integrity=True)

print(stat.shape)
print(stat_comb.shape)
print("######## stat_comb ##### ")
stat_comb[['file name', 'partind']] = stat_comb['export name'].str.split('-',expand=True) 
print(stat_comb.columns)
print(stat_comb.head(3))
stat_comb = stat_comb[(stat_comb['depth']> 1)]
print('stat_comb.shape ',stat_comb.shape)
#silc_to_bmp(stat_comb['file name'].tolist(), RAWDIR, RAWBMP)
#stat_comb.to_csv(SilCamDataPath + '/stat_comb.csv', index = False, header=True)
print(stat_comb['file name'].tolist()[:2])
# Out:
# highest prob  (888073, 20)
# stat.shape after extract middle (391605, 20)
# stat.head                                   index  equivalent_diameter  \
# timestamp
# 2020-04-20 09:43:19.360874+00:00      6             3.908820
# 2020-04-20 09:43:19.360874+00:00      7             4.787307
# 2020-04-20 09:43:19.360874+00:00      8             4.513517
#
#                                                   export name  \
# timestamp
# 2020-04-20 09:43:19.360874+00:00  D20200420T094319.360874-PN6
# 2020-04-20 09:43:19.360874+00:00  D20200420T094319.360874-PN7
# 2020-04-20 09:43:19.360874+00:00  D20200420T094319.360874-PN8
#
#                                   major_axis_length    maxc   maxr    minc  \
# timestamp
# 2020-04-20 09:43:19.360874+00:00           6.252759  1097.0  392.0  1091.0
# 2020-04-20 09:43:19.360874+00:00           7.242021  1138.0  404.0  1133.0
# 2020-04-20 09:43:19.360874+00:00           6.568894  1161.0  412.0  1155.0
#
#                                   minor_axis_length   minr  particle index  \
# timestamp
# 2020-04-20 09:43:19.360874+00:00           3.335450  388.0               6
# 2020-04-20 09:43:19.360874+00:00           4.024315  397.0               7
# 2020-04-20 09:43:19.360874+00:00           6.029066  405.0               8
#
#                                   probability_bubble  probability_copepod  \
# timestamp
# 2020-04-20 09:43:19.360874+00:00            0.431572             0.001982
# 2020-04-20 09:43:19.360874+00:00            0.612146             0.001922
# 2020-04-20 09:43:19.360874+00:00            0.500671             0.002224
#
#                                   probability_diatom_chain  \
# timestamp
# 2020-04-20 09:43:19.360874+00:00                  0.003191
# 2020-04-20 09:43:19.360874+00:00                  0.002930
# 2020-04-20 09:43:19.360874+00:00                  0.005703
#
#                                   probability_faecal_pellets  probability_oil  \
# timestamp
# 2020-04-20 09:43:19.360874+00:00                    0.002293         0.396245
# 2020-04-20 09:43:19.360874+00:00                    0.001856         0.213425
# 2020-04-20 09:43:19.360874+00:00                    0.002639         0.342152
#
#                                   probability_oily_gas  probability_other  \
# timestamp
# 2020-04-20 09:43:19.360874+00:00              0.098708           0.066009
# 2020-04-20 09:43:19.360874+00:00              0.102975           0.064747
# 2020-04-20 09:43:19.360874+00:00              0.091828           0.054783
#
#                                   saturation  solidity  highest prob
# timestamp
# 2020-04-20 09:43:19.360874+00:00    1.972674  0.750000      0.431572
# 2020-04-20 09:43:19.360874+00:00    1.972674  0.782609      0.612146
# 2020-04-20 09:43:19.360874+00:00    1.972674  0.571429      0.500671
# (11188, 20)
# (4708, 53)
# ######## stat_comb #####
# Index(['index', 'equivalent_diameter', 'export name', 'major_axis_length',
#        'maxc', 'maxr', 'minc', 'minor_axis_length', 'minr', 'particle index',
#        'probability_bubble', 'probability_copepod', 'probability_diatom_chain',
#        'probability_faecal_pellets', 'probability_oil', 'probability_oily_gas',
#        'probability_other', 'saturation', 'solidity', 'highest prob',
#        'AirSaturation', 'Chlorophyll', 'Conductivity', 'DissolvedOxygen',
#        'lat', 'lon', 'height', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'u', 'v',
#        'w', 'vx', 'vy', 'vz', 'p', 'q', 'r', 'depth', 'alt', 'Pressure', 'Rpm',
#        'Salinity', 'Temperature', 'Turbidity', 'WaterDensity', 'wv_x', 'wv_y',
#        'wv_z', 'file name', 'partind'],
#       dtype='object')
#                                   index  equivalent_diameter  \
# timestamp
# 2020-04-20 09:43:55.496705+00:00  14621             5.753627
# 2020-04-20 09:43:55.747579+00:00  14688             5.046265
# 2020-04-20 09:43:55.998580+00:00  14755             8.058239
#
#                                                    export name  \
# timestamp
# 2020-04-20 09:43:55.496705+00:00  D20200420T094355.496705-PN24
# 2020-04-20 09:43:55.747579+00:00  D20200420T094355.747579-PN11
# 2020-04-20 09:43:55.998580+00:00  D20200420T094355.998580-PN13
#
#                                   major_axis_length    maxc   maxr    minc  \
# timestamp
# 2020-04-20 09:43:55.496705+00:00           6.587119   352.0  470.0   345.0
# 2020-04-20 09:43:55.747579+00:00           6.645103  1941.0  559.0  1937.0
# 2020-04-20 09:43:55.998580+00:00          11.414266  1916.0  377.0  1908.0
#
#                                   minor_axis_length   minr  particle index  \
# timestamp
# 2020-04-20 09:43:55.496705+00:00           5.843657  464.0              24
# 2020-04-20 09:43:55.747579+00:00           3.837005  552.0              11
# 2020-04-20 09:43:55.998580+00:00           6.264928  364.0              13
#
#                                    ...      Rpm  Salinity  Temperature  \
# timestamp                          ...
# 2020-04-20 09:43:55.496705+00:00   ...     1353    13.383        5.195
# 2020-04-20 09:43:55.747579+00:00   ...     1353    13.383        5.195
# 2020-04-20 09:43:55.998580+00:00   ...     1428    13.504        5.216
#
#                                   Turbidity  WaterDensity      wv_x      wv_y  \
# timestamp
# 2020-04-20 09:43:55.496705+00:00    342.857      1010.572  1.287212 -0.213832
# 2020-04-20 09:43:55.747579+00:00    342.857      1010.572  1.287212 -0.213832
# 2020-04-20 09:43:55.998580+00:00    342.857      1010.668  1.446803 -0.182926
#
#                                       wv_z                file name  partind
# timestamp
# 2020-04-20 09:43:55.496705+00:00 -0.132901  D20200420T094355.496705     PN24
# 2020-04-20 09:43:55.747579+00:00 -0.132901  D20200420T094355.747579     PN11
# 2020-04-20 09:43:55.998580+00:00 -0.065758  D20200420T094355.998580     PN13
#
# [3 rows x 55 columns]
# stat_comb.shape  (4228, 55)
# ['D20200420T094359.004164', 'D20200420T094359.256260']

# %%
print(stat.shape)
stat = stat.dropna()
print(stat.shape)
print(stat_comb.shape)

df_extract = extract_to_roi(stat, stat_comb, roidir, 
                            extdir, 
                            msize=40, minimgsize=1000)
print(df_extract.shape)
if(df_extract.shape[0] > 0):
    objects_to_file(df_extract, roidir, extdir)
else:
    print('Extracted objects are too small!')
# Out:
# (11188, 20)
# (11188, 20)
# (4228, 55)
# inside export_name2im D20200420T094359.004164-PN35
# inside export_name2im D20200420T094359.256260-PN36
# inside export_name2im D20200420T094359.504401-PN54
# inside export_name2im D20200420T094359.755118-PN28
# inside export_name2im D20200420T094400.006455-PN16
# inside export_name2im D20200420T094400.258012-PN51
# inside export_name2im D20200420T094400.510181-PN76
# inside export_name2im D20200420T094400.761282-PN46
# inside export_name2im D20200420T094401.012978-PN84
# inside export_name2im D20200420T094401.264260-PN17
# inside export_name2im D20200420T094401.512656-PN7
# inside export_name2im D20200420T094401.764104-PN1
# inside export_name2im D20200420T094402.013694-PN29
# inside export_name2im D20200420T094402.264650-PN1
# inside export_name2im D20200420T094402.516520-PN20
# inside export_name2im D20200420T094402.767577-PN42
# inside export_name2im D20200420T094403.018679-PN26
# inside export_name2im D20200420T094403.270220-PN43
# inside export_name2im D20200420T094403.518845-PN51
# inside export_name2im D20200420T094403.770585-PN13
# inside export_name2im D20200420T094404.022212-PN58
# inside export_name2im D20200420T094632.642786-PN11
# inside export_name2im D20200420T094632.892219-PN104
# inside export_name2im D20200420T094633.144010-PN112
# inside export_name2im D20200420T094633.643169-PN85
# inside export_name2im D20200420T094633.894745-PN191
# inside export_name2im D20200420T094634.145546-PN3
# inside export_name2im D20200420T094634.393925-PN43
# inside export_name2im D20200420T094634.645441-PN163
# inside export_name2im D20200420T094634.894848-PN139
# inside export_name2im D20200420T094635.144177-PN123
# inside export_name2im D20200420T094635.396395-PN107
# inside export_name2im D20200420T094635.648798-PN18
# inside export_name2im D20200420T094635.900226-PN62
# inside export_name2im D20200420T094636.152243-PN4
# inside export_name2im D20200420T094636.404475-PN62
# inside export_name2im D20200420T094636.653813-PN94
# inside export_name2im D20200420T094636.904243-PN49
# inside export_name2im D20200420T100255.079515-PN99
# inside export_name2im D20200420T100255.334138-PN34
# inside export_name2im D20200420T100256.086164-PN12
# inside export_name2im D20200420T100256.338429-PN18
# inside export_name2im D20200420T100256.591026-PN54
# inside export_name2im D20200420T100257.091251-PN42
# inside export_name2im D20200420T100257.343290-PN102
# inside export_name2im D20200420T100257.594444-PN8
# inside export_name2im D20200420T100257.846068-PN100
# inside export_name2im D20200420T100258.096840-PN22
# inside export_name2im D20200420T100258.348433-PN25
# inside export_name2im D20200420T100258.597622-PN58
# inside export_name2im D20200420T100258.850271-PN13
# inside export_name2im D20200420T100259.100714-PN47
# inside export_name2im D20200420T100259.349727-PN20
# inside export_name2im D20200420T100259.598854-PN47
# inside export_name2im D20200420T100300.096973-PN17
# inside export_name2im D20200420T100300.347819-PN35
# inside export_name2im D20200420T100300.598865-PN126
# inside export_name2im D20200420T100300.850812-PN107
# inside export_name2im D20200420T100301.099965-PN33
# inside export_name2im D20200420T100301.351591-PN8
# inside export_name2im D20200420T100301.602136-PN19
# inside export_name2im D20200420T100301.851603-PN24
# inside export_name2im D20200420T100302.100953-PN2
# inside export_name2im D20200420T100302.352139-PN14
# inside export_name2im D20200420T100302.602419-PN18
# inside export_name2im D20200420T100302.853934-PN7
# inside export_name2im D20200420T100303.353616-PN8
# inside export_name2im D20200420T100303.604029-PN156
# inside export_name2im D20200420T100303.852917-PN82
# inside export_name2im D20200420T100304.105329-PN58
# inside export_name2im D20200420T100304.604629-PN35
# inside export_name2im D20200420T100304.854284-PN73
# inside export_name2im D20200420T100305.102731-PN6
# inside export_name2im D20200420T100305.353544-PN56
# inside export_name2im D20200420T100305.853928-PN8
# inside export_name2im D20200420T100306.105977-PN77
# inside export_name2im D20200420T100306.608046-PN81
# inside export_name2im D20200420T100306.859218-PN41
# inside export_name2im D20200420T100307.360737-PN62
# inside export_name2im D20200420T100307.609718-PN9
# inside export_name2im D20200420T100307.861234-PN11
# inside export_name2im D20200420T100308.112962-PN10
# inside export_name2im D20200420T100308.365434-PN34
# inside export_name2im D20200420T100308.614461-PN53
# inside export_name2im D20200420T100309.115875-PN64
# inside export_name2im D20200420T100309.368052-PN45
# inside export_name2im D20200420T100309.867312-PN89
# inside export_name2im D20200420T100310.366167-PN25
# inside export_name2im D20200420T100310.615830-PN0
# inside export_name2im D20200420T100310.867624-PN9
# inside export_name2im D20200420T100311.117851-PN25
# inside export_name2im D20200420T100311.370466-PN9
# inside export_name2im D20200420T100311.622210-PN65
# inside export_name2im D20200420T100311.871411-PN37
# inside export_name2im D20200420T100312.119879-PN27
# inside export_name2im D20200420T100312.372289-PN9
# inside export_name2im D20200420T100312.621375-PN49
# inside export_name2im D20200420T100312.872224-PN20
# inside export_name2im D20200420T100313.123249-PN68
# inside export_name2im D20200420T100313.872315-PN12
# inside export_name2im D20200420T100314.122221-PN35
# inside export_name2im D20200420T100314.372143-PN37
# inside export_name2im D20200420T100314.624078-PN23
# inside export_name2im D20200420T100314.873026-PN5
# inside export_name2im D20200420T100315.124858-PN18
# inside export_name2im D20200420T100315.377163-PN22
# inside export_name2im D20200420T100315.627420-PN23
# inside export_name2im D20200420T100315.877403-PN8
# inside export_name2im D20200420T100316.127209-PN24
# inside export_name2im D20200420T100316.376366-PN9
# inside export_name2im D20200420T100316.625106-PN32
# inside export_name2im D20200420T100316.875928-PN41
# inside export_name2im D20200420T100317.127033-PN61
# inside export_name2im D20200420T100317.377050-PN43
# inside export_name2im D20200420T100317.625625-PN65
# inside export_name2im D20200420T100317.877009-PN11
# inside export_name2im D20200420T100318.381758-PN38
# inside export_name2im D20200420T100318.631170-PN58
# inside export_name2im D20200420T100318.879735-PN58
# inside export_name2im D20200420T100319.132282-PN2
# inside export_name2im D20200420T100319.383134-PN19
# inside export_name2im D20200420T100319.884150-PN12
# inside export_name2im D20200420T100320.134760-PN7
# inside export_name2im D20200420T100320.385162-PN14
# inside export_name2im D20200420T100320.635516-PN9
# inside export_name2im D20200420T100321.138111-PN41
# inside export_name2im D20200420T100321.386720-PN58
# inside export_name2im D20200420T100322.388911-PN21
# inside export_name2im D20200420T100322.641383-PN24
# inside export_name2im D20200420T100322.893386-PN53
# inside export_name2im D20200420T100323.142869-PN18
# inside export_name2im D20200420T100323.393885-PN15
# inside export_name2im D20200420T100323.643735-PN38
# inside export_name2im D20200420T100323.892139-PN17
# inside export_name2im D20200420T100324.142383-PN22
# inside export_name2im D20200420T100324.644538-PN11
# inside export_name2im D20200420T100325.148809-PN36
# inside export_name2im D20200420T100325.399576-PN55
# inside export_name2im D20200420T100325.652132-PN32
# inside export_name2im D20200420T100325.904900-PN34
# inside export_name2im D20200420T100326.154586-PN9
# inside export_name2im D20200420T100326.406259-PN28
# inside export_name2im D20200420T100326.657429-PN8
# inside export_name2im D20200420T100326.907601-PN50
# inside export_name2im D20200420T100327.156820-PN20
# inside export_name2im D20200420T100327.406089-PN39
# inside export_name2im D20200420T100327.908411-PN45
# inside export_name2im D20200420T100328.158855-PN45
# inside export_name2im D20200420T100328.660012-PN5
# inside export_name2im D20200420T100329.164455-PN11
# inside export_name2im D20200420T100329.669529-PN3
# inside export_name2im D20200420T100329.918324-PN28
# inside export_name2im D20200420T100330.417918-PN8
# inside export_name2im D20200420T100330.669250-PN55
# inside export_name2im D20200420T100330.921096-PN21
# inside export_name2im D20200420T100331.666259-PN31
# inside export_name2im D20200420T100331.920200-PN17
# inside export_name2im D20200420T100332.421745-PN19
# inside export_name2im D20200420T100332.672241-PN18
# inside export_name2im D20200420T100332.922235-PN38
# inside export_name2im D20200420T100333.171510-PN20
# inside export_name2im D20200420T100333.423846-PN46
# inside export_name2im D20200420T100334.175542-PN23
# inside export_name2im D20200420T100334.676823-PN38
# inside export_name2im D20200420T100335.178846-PN28
# inside export_name2im D20200420T100335.430125-PN0
# inside export_name2im D20200420T100335.682289-PN11
# inside export_name2im D20200420T100335.931185-PN5
# inside export_name2im D20200420T100336.180705-PN37
# inside export_name2im D20200420T100336.683232-PN33
# inside export_name2im D20200420T100336.933019-PN3
# inside export_name2im D20200420T100337.182113-PN37
# inside export_name2im D20200420T100337.433908-PN28
# inside export_name2im D20200420T100338.185825-PN4
# inside export_name2im D20200420T100338.435284-PN19
# inside export_name2im D20200420T100338.687687-PN7
# inside export_name2im D20200420T100339.188497-PN43
# inside export_name2im D20200420T100339.439689-PN18
# inside export_name2im D20200420T100339.691931-PN7
# inside export_name2im D20200420T100339.944296-PN35
# inside export_name2im D20200420T100340.443762-PN3
# inside export_name2im D20200420T100340.696387-PN24
# inside export_name2im D20200420T100340.948688-PN6
# inside export_name2im D20200420T100341.198239-PN22
# inside export_name2im D20200420T100341.448694-PN22
# inside export_name2im D20200420T100341.701045-PN32
# inside export_name2im D20200420T100341.950616-PN47
# inside export_name2im D20200420T100342.203200-PN22
# inside export_name2im D20200420T100342.452421-PN42
# inside export_name2im D20200420T100342.951601-PN20
# inside export_name2im D20200420T100343.200692-PN42
# inside export_name2im D20200420T100343.450039-PN24
# inside export_name2im D20200420T100343.698618-PN42
# inside export_name2im D20200420T100343.949314-PN4
# inside export_name2im D20200420T100344.199358-PN29
# inside export_name2im D20200420T100344.447830-PN17
# inside export_name2im D20200420T100344.699611-PN4
# inside export_name2im D20200420T100344.948086-PN12
# inside export_name2im D20200420T100346.194028-PN1
# inside export_name2im D20200420T100346.441537-PN22
# inside export_name2im D20200420T100346.944303-PN36
# inside export_name2im D20200420T100347.196841-PN30
# inside export_name2im D20200420T100347.448259-PN33
# inside export_name2im D20200420T100347.699186-PN33
# inside export_name2im D20200420T100347.951628-PN30
# inside export_name2im D20200420T100348.199932-PN8
# inside export_name2im D20200420T100348.451655-PN9
# inside export_name2im D20200420T100348.703941-PN15
# inside export_name2im D20200420T100348.956606-PN5
# inside export_name2im D20200420T100349.205153-PN29
# inside export_name2im D20200420T100349.705327-PN31
# inside export_name2im D20200420T100349.954421-PN2
# inside export_name2im D20200420T100350.205338-PN35
# inside export_name2im D20200420T100350.708810-PN29
# inside export_name2im D20200420T100352.958979-PN17
# inside export_name2im D20200420T100353.458031-PN23
# inside export_name2im D20200420T100353.959230-PN3
# inside export_name2im D20200420T100354.209384-PN12
# inside export_name2im D20200420T100355.213159-PN37
# inside export_name2im D20200420T100356.212349-PN14
# inside export_name2im D20200420T100356.462168-PN8
# inside export_name2im D20200420T100356.710859-PN46
# inside export_name2im D20200420T100356.963306-PN15
# inside export_name2im D20200420T100357.216308-PN18
# inside export_name2im D20200420T100357.715634-PN8
# inside export_name2im D20200420T100358.216407-PN17
# inside export_name2im D20200420T100358.971395-PN1
# inside export_name2im D20200420T100359.221318-PN24
# inside export_name2im D20200420T100359.471514-PN10
# inside export_name2im D20200420T100359.723702-PN64
# inside export_name2im D20200420T100400.225040-PN51
# inside export_name2im D20200420T100400.476494-PN14
# inside export_name2im D20200420T100400.725085-PN29
# inside export_name2im D20200420T100400.973731-PN31
# inside export_name2im D20200420T100401.225465-PN29
# inside export_name2im D20200420T100401.477037-PN69
# inside export_name2im D20200420T100401.729467-PN46
# inside export_name2im D20200420T100402.480692-PN20
# inside export_name2im D20200420T100402.729865-PN49
# inside export_name2im D20200420T100403.229672-PN9
# inside export_name2im D20200420T100403.734799-PN49
# inside export_name2im D20200420T100403.987419-PN48
# inside export_name2im D20200420T100404.236290-PN56
# inside export_name2im D20200420T100404.739383-PN11
# inside export_name2im D20200420T100404.988924-PN24
# inside export_name2im D20200420T100405.238963-PN41
# inside export_name2im D20200420T100405.488480-PN17
# inside export_name2im D20200420T100405.736342-PN3
# inside export_name2im D20200420T100406.987651-PN42
# inside export_name2im D20200420T100407.237076-PN36
# inside export_name2im D20200420T100407.489076-PN16
# inside export_name2im D20200420T100407.738904-PN48
# inside export_name2im D20200420T100407.988049-PN9
# inside export_name2im D20200420T100408.487313-PN33
# inside export_name2im D20200420T100408.738367-PN16
# inside export_name2im D20200420T100408.989100-PN54
# inside export_name2im D20200420T100409.239895-PN33
# inside export_name2im D20200420T100409.995662-PN17
# inside export_name2im D20200420T100410.245216-PN63
# inside export_name2im D20200420T100410.496388-PN15
# inside export_name2im D20200420T100410.747588-PN61
# inside export_name2im D20200420T100411.999733-PN31
# inside export_name2im D20200420T100412.251422-PN67
# inside export_name2im D20200420T100412.502555-PN15
# inside export_name2im D20200420T100412.755325-PN11
# inside export_name2im D20200420T100413.004536-PN54
# inside export_name2im D20200420T100413.253718-PN19
# inside export_name2im D20200420T100413.504443-PN50
# inside export_name2im D20200420T100414.253858-PN34
# inside export_name2im D20200420T100415.256495-PN31
# inside export_name2im D20200420T100415.505746-PN34
# inside export_name2im D20200420T100415.758353-PN13
# inside export_name2im D20200420T100416.257699-PN45
# inside export_name2im D20200420T100416.757358-PN18
# inside export_name2im D20200420T100417.009892-PN62
# inside export_name2im D20200420T100417.260918-PN70
# inside export_name2im D20200420T100417.761957-PN11
# inside export_name2im D20200420T100418.011240-PN54
# inside export_name2im D20200420T100419.014483-PN44
# inside export_name2im D20200420T100419.511281-PN26
# inside export_name2im D20200420T100419.760420-PN45
# inside export_name2im D20200420T100420.012288-PN22
# inside export_name2im D20200420T100420.264486-PN0
# inside export_name2im D20200420T100420.512423-PN26
# inside export_name2im D20200420T100420.762828-PN57
# inside export_name2im D20200420T100421.014705-PN21
# inside export_name2im D20200420T100421.516394-PN49
# inside export_name2im D20200420T100421.766219-PN4
# inside export_name2im D20200420T100423.020788-PN5
# inside export_name2im D20200420T100423.522037-PN23
# inside export_name2im D20200420T100423.773767-PN35
# inside export_name2im D20200420T100424.026009-PN23
# inside export_name2im D20200420T100424.276250-PN29
# inside export_name2im D20200420T100424.528051-PN14
# inside export_name2im D20200420T100424.776440-PN22
# inside export_name2im D20200420T100425.025040-PN54
# inside export_name2im D20200420T100425.275104-PN37
# inside export_name2im D20200420T100425.774790-PN57
# inside export_name2im D20200420T100426.275028-PN39
# inside export_name2im D20200420T100426.526703-PN34
# inside export_name2im D20200420T100427.025617-PN62
# inside export_name2im D20200420T100427.276938-PN23
# inside export_name2im D20200420T100427.528246-PN63
# inside export_name2im D20200420T100427.777400-PN33
# inside export_name2im D20200420T100428.028834-PN54
# inside export_name2im D20200420T100428.278330-PN26
# inside export_name2im D20200420T100428.527036-PN57
# inside export_name2im D20200420T100428.777156-PN15
# inside export_name2im D20200420T100429.027235-PN64
# inside export_name2im D20200420T100429.277959-PN34
# inside export_name2im D20200420T100429.530340-PN18
# inside export_name2im D20200420T100429.781464-PN73
# inside export_name2im D20200420T100430.282272-PN24
# inside export_name2im D20200420T100430.534614-PN40
# inside export_name2im D20200420T100431.033488-PN17
# inside export_name2im D20200420T100431.534918-PN20
# inside export_name2im D20200420T100431.785994-PN50
# inside export_name2im D20200420T100432.037471-PN2
# inside export_name2im D20200420T100432.539281-PN35
# inside export_name2im D20200420T100433.291949-PN43
# inside export_name2im D20200420T100433.541207-PN22
# inside export_name2im D20200420T100433.789878-PN39
# inside export_name2im D20200420T100434.290525-PN15
# inside export_name2im D20200420T100434.542947-PN7
# inside export_name2im D20200420T100434.791593-PN75
# inside export_name2im D20200420T100435.041499-PN38
# inside export_name2im D20200420T100435.291719-PN39
# inside export_name2im D20200420T100435.543480-PN64
# inside export_name2im D20200420T100435.791701-PN24
# inside export_name2im D20200420T100436.040371-PN58
# inside export_name2im D20200420T100436.289765-PN79
# inside export_name2im D20200420T100436.541217-PN1
# inside export_name2im D20200420T100436.790750-PN61
# inside export_name2im D20200420T100437.040738-PN32
# inside export_name2im D20200420T100437.543830-PN15
# inside export_name2im D20200420T100437.795516-PN39
# inside export_name2im D20200420T100438.046095-PN51
# inside export_name2im D20200420T100438.297173-PN39
# inside export_name2im D20200420T100438.548990-PN69
# inside export_name2im D20200420T100438.798977-PN86
# inside export_name2im D20200420T100439.050208-PN46
# inside export_name2im D20200420T100439.797379-PN38
# inside export_name2im D20200420T100440.049030-PN51
# inside export_name2im D20200420T100440.297945-PN68
# inside export_name2im D20200420T100440.552402-PN1
# inside export_name2im D20200420T100441.550294-PN48
# inside export_name2im D20200420T100442.048532-PN45
# inside export_name2im D20200420T100442.299667-PN40
# inside export_name2im D20200420T100442.549068-PN73
# inside export_name2im D20200420T100442.800668-PN68
# inside export_name2im D20200420T100443.053112-PN10
# inside export_name2im D20200420T100443.302038-PN34
# inside export_name2im D20200420T100443.552734-PN5
# inside export_name2im D20200420T100443.803272-PN15
# inside export_name2im D20200420T100444.304269-PN21
# inside export_name2im D20200420T100444.554804-PN9
# inside export_name2im D20200420T100444.807118-PN51
# inside export_name2im D20200420T100445.311612-PN56
# inside export_name2im D20200420T100446.064589-PN8
# inside export_name2im D20200420T100446.567360-PN54
# inside export_name2im D20200420T100446.816449-PN49
# inside export_name2im D20200420T100447.068074-PN76
# inside export_name2im D20200420T100447.819306-PN42
# inside export_name2im D20200420T100448.068107-PN21
# inside export_name2im D20200420T100448.568524-PN16
# inside export_name2im D20200420T100448.817978-PN47
# inside export_name2im D20200420T100449.068223-PN42
# inside export_name2im D20200420T100449.566092-PN81
# inside export_name2im D20200420T100450.063752-PN33
# inside export_name2im D20200420T100450.315629-PN24
# inside export_name2im D20200420T100450.566032-PN93
# inside export_name2im D20200420T100451.066613-PN12
# inside export_name2im D20200420T100451.318479-PN113
# inside export_name2im D20200420T100451.570701-PN94
# inside export_name2im D20200420T100451.820349-PN41
# inside export_name2im D20200420T100452.070716-PN70
# inside export_name2im D20200420T100452.322645-PN29
# inside export_name2im D20200420T100452.571231-PN44
# inside export_name2im D20200420T100452.823410-PN141
# inside export_name2im D20200420T100453.075849-PN85
# inside export_name2im D20200420T100453.581107-PN21
# inside export_name2im D20200420T100453.833532-PN53
# inside export_name2im D20200420T100454.084670-PN51
# inside export_name2im D20200420T100454.835290-PN18
# inside export_name2im D20200420T100455.336657-PN30
# inside export_name2im D20200420T100455.587577-PN14
# inside export_name2im D20200420T100455.837295-PN92
# inside export_name2im D20200420T100456.089205-PN133
# inside export_name2im D20200420T100457.093235-PN22
# inside export_name2im D20200420T100457.343369-PN107
# inside export_name2im D20200420T100457.594065-PN84
# inside export_name2im D20200420T100457.843469-PN111
# inside export_name2im D20200420T100458.095627-PN76
# inside export_name2im D20200420T100458.344870-PN103
# inside export_name2im D20200420T100458.845683-PN40
# inside export_name2im D20200420T100459.097722-PN43
# inside export_name2im D20200420T100459.346753-PN65
# inside export_name2im D20200420T100459.598499-PN17
# inside export_name2im D20200420T100459.847167-PN116
# inside export_name2im D20200420T100500.098756-PN1
# inside export_name2im D20200420T100500.350516-PN21
# inside export_name2im D20200420T100500.852149-PN61
# inside export_name2im D20200420T100501.103480-PN40
# inside export_name2im D20200420T100501.353546-PN23
# inside export_name2im D20200420T100501.602566-PN39
# inside export_name2im D20200420T100501.851599-PN14
# inside export_name2im D20200420T100502.103194-PN4
# inside export_name2im D20200420T100502.352569-PN125
# inside export_name2im D20200420T100502.603078-PN115
# inside export_name2im D20200420T100502.852880-PN45
# inside export_name2im D20200420T100503.104297-PN52
# inside export_name2im D20200420T100503.356669-PN130
# inside export_name2im D20200420T100503.607067-PN26
# inside export_name2im D20200420T100503.858880-PN98
# inside export_name2im D20200420T100504.110739-PN91
# inside export_name2im D20200420T100504.361071-PN57
# inside export_name2im D20200420T100504.611227-PN87
# inside export_name2im D20200420T100504.861396-PN159
# inside export_name2im D20200420T100505.359572-PN9
# inside export_name2im D20200420T100505.611555-PN124
# inside export_name2im D20200420T100505.860006-PN110
# inside export_name2im D20200420T100506.111392-PN77
# inside export_name2im D20200420T100506.361146-PN26
# inside export_name2im D20200420T100506.613028-PN53
# inside export_name2im D20200420T100506.861991-PN44
# inside export_name2im D20200420T100507.114289-PN165
# inside export_name2im D20200420T100507.364412-PN102
# inside export_name2im D20200420T100507.613467-PN44
# inside export_name2im D20200420T100507.865051-PN36
# inside export_name2im D20200420T100508.117897-PN36
# inside export_name2im D20200420T100508.367597-PN185
# inside export_name2im D20200420T100508.617424-PN162
# inside export_name2im D20200420T100508.866428-PN3
# inside export_name2im D20200420T100509.118930-PN19
# inside export_name2im D20200420T100509.367729-PN68
# inside export_name2im D20200420T100509.618266-PN55
# inside export_name2im D20200420T100509.870305-PN102
# inside export_name2im D20200420T100510.118990-PN22
# inside export_name2im D20200420T100510.368876-PN18
# inside export_name2im D20200420T100510.617955-PN33
# inside export_name2im D20200420T100510.869552-PN1
# inside export_name2im D20200420T100511.119744-PN53
# inside export_name2im D20200420T100511.370674-PN176
# inside export_name2im D20200420T100511.619893-PN104
# inside export_name2im D20200420T100511.868903-PN69
# inside export_name2im D20200420T100512.120315-PN42
# inside export_name2im D20200420T100512.371964-PN94
# inside export_name2im D20200420T100512.624121-PN25
# inside export_name2im D20200420T100512.873009-PN47
# inside export_name2im D20200420T100513.121549-PN14
# inside export_name2im D20200420T100513.371672-PN137
# inside export_name2im D20200420T100513.620747-PN115
# inside export_name2im D20200420T100513.873522-PN128
# inside export_name2im D20200420T100514.124722-PN51
# inside export_name2im D20200420T100514.629208-PN29
# inside export_name2im D20200420T100514.881305-PN89
# inside export_name2im D20200420T100515.132014-PN11
# inside export_name2im D20200420T100515.632134-PN124
# inside export_name2im D20200420T100515.884251-PN67
# inside export_name2im D20200420T100516.133680-PN19
# inside export_name2im D20200420T100516.385419-PN184
# inside export_name2im D20200420T100516.635410-PN66
# inside export_name2im D20200420T100516.888018-PN31
# inside export_name2im D20200420T100517.140135-PN105
# inside export_name2im D20200420T100517.388148-PN100
# inside export_name2im D20200420T100517.637911-PN116
# inside export_name2im D20200420T100517.887293-PN110
# inside export_name2im D20200420T100518.138579-PN67
# inside export_name2im D20200420T100519.141762-PN200
# inside export_name2im D20200420T100519.390369-PN51
# inside export_name2im D20200420T100519.642601-PN141
# inside export_name2im D20200420T100519.892860-PN176
# inside export_name2im D20200420T100520.144813-PN189
# inside export_name2im D20200420T100520.394463-PN86
# inside export_name2im D20200420T100520.644413-PN141
# ...
# inside export_name2im D20200420T121624.396058-PN39
# inside export_name2im D20200420T121624.648204-PN21
# inside export_name2im D20200420T121625.144645-PN55
# inside export_name2im D20200420T121625.397894-PN36
# inside export_name2im D20200420T121626.906519-PN28
# inside export_name2im D20200420T121627.159874-PN22
# inside export_name2im D20200420T121627.409186-PN11
# inside export_name2im D20200420T121627.660115-PN13
# inside export_name2im D20200420T121628.161744-PN17
# inside export_name2im D20200420T121628.410614-PN28
# inside export_name2im D20200420T121628.661164-PN30
:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/ext\D20200420T094624.370269-PN198.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200420T100346.944303-PN36
# inside export_name2im D20200420T102550.683368-PN5
# inside export_name2im D20200420T102550.683368-PN23
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/ext\D20200420T102550.683368-PN23.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200420T102550.683368-PN33
# inside export_name2im D20200420T102550.683368-PN37
# inside export_name2im D20200420T113835.193783-PN16
# inside export_name2im D20200420T120931.848444-PN18
# inside export_name2im D20200420T120931.848444-PN60
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/ext\D20200420T120931.848444-PN60.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200420T120931.848444-PN177
# C:\ProgramData\anaconda3\envs\silcamfw\lib\site-packages\skimage\io\_io.py:141: UserWarning: F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/ext\D20200420T120931.848444-PN177.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)
# inside export_name2im D20200420T121523.742944-PN22
# export completed!

# %%
print(df_extract.shape)
scenes = []
for f in df_extract['export name'].tolist():
    n = f.split('-')[0]
    if n not in scenes: 
        scenes.append(n)
print(len(scenes))
silc_to_bmp(scenes, RAWDIR, RAWBMP)
print(df_extract)
# Out:
# (12, 20)
# 6
# Creation of the directory F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-20/RAWBMP failed
# conversion completed!
#                                    index  equivalent_diameter  \
# timestamp
# 2020-04-20 09:46:24.370269+00:00   79687            18.159544
# 2020-04-20 09:46:24.370269+00:00   79756             4.370194
# 2020-04-20 10:03:46.944303+00:00  170430            26.939683
# 2020-04-20 10:25:50.683368+00:00  280325            36.196181
# 2020-04-20 10:25:50.683368+00:00  280343             9.373021
# 2020-04-20 10:25:50.683368+00:00  280353            12.716187
# 2020-04-20 10:25:50.683368+00:00  280357            10.155413
# 2020-04-20 11:38:35.193783+00:00  475419            24.747287
# 2020-04-20 12:09:31.848444+00:00  723185            39.461018
# 2020-04-20 12:09:31.848444+00:00  723227             3.908820
# 2020-04-20 12:09:31.848444+00:00  723344             4.370194
# 2020-04-20 12:15:23.742944+00:00  786297            23.989670
#
#                                                     export name  \
# timestamp
# 2020-04-20 09:46:24.370269+00:00  D20200420T094624.370269-PN129
# 2020-04-20 09:46:24.370269+00:00  D20200420T094624.370269-PN198
# 2020-04-20 10:03:46.944303+00:00   D20200420T100346.944303-PN36
# 2020-04-20 10:25:50.683368+00:00    D20200420T102550.683368-PN5
# 2020-04-20 10:25:50.683368+00:00   D20200420T102550.683368-PN23
# 2020-04-20 09:46:24.370269+00:00    0.421781  0.937500      0.999556
# 2020-04-20 10:03:46.944303+00:00    0.213946  0.766129      0.971746
# 2020-04-20 10:25:50.683368+00:00    0.287608  0.843443      0.959124
# 2020-04-20 10:25:50.683368+00:00    0.287608  0.841463      0.999975
# 2020-04-20 10:25:50.683368+00:00    0.287608  0.894366      0.991730
# 2020-04-20 10:25:50.683368+00:00    0.287608  0.931034      0.978718
# 2020-04-20 11:38:35.193783+00:00    0.236995  0.818027      0.999595
# 2020-04-20 12:09:31.848444+00:00    0.517031  0.920241      0.984422
# 2020-04-20 12:09:31.848444+00:00    0.517031  0.923077      0.999997
# 2020-04-20 12:09:31.848444+00:00    0.517031  0.882353      0.993573
# 2020-04-20 12:15:23.742944+00:00    0.146328  0.826325      0.999999

# %%
RAWSPEEDBMP = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/RawSpeeds03"
# D20200423T103327.892945  -- 1.258843m/s     -- 1337   rpm      -- April mission (1)
# D20200423T111851.909500  -- 1.516541m/s     -- 1337   rpm      -- April mission (2)
# D20200423T131825.448647  -- 1.945775m/s     -- 1330.5 rpm    -- April mission (3)
speed_int = [0,10000]
scenes = ['D20200423T103327.892945', 'D20200423T111851.909500', 'D20200423T131825.448647']
new_stat = stat_comb.loc[sum([stat_comb['export name'].str.contains(f) for f in scenes]) > 0]
print("####### stat_comb ######")
print(stat_comb.loc[sum([stat_comb['export name'].str.contains(f) for f in scenes]) > 0])
print("####### new_stat ######")
print(new_stat.head)
if len(new_stat) > 0:
    #new_stat = new_stat.reset_index()
    #stat.set_index('timestamp', inplace=True)
    #new_stat = new_stat.tz_localize('UTC')
    #new_stat.index = new_stat.index.tz_convert(tz='UTC')
    #new_stat = new_stat.reset_index()
    print(new_stat.columns)
    silc_to_bmp(new_stat['file name'].tolist(), RAWDIR, RAWSPEEDBMP + str(speed_int[0]) + '_' + str(speed_int[1]))
    new_stat[['file name', 'depth', 'Rpm', 'wv_x']].to_csv(RAWSPEEDBMP + str(speed_int[0]) + '_' + str(speed_int[1]) 
                    + '/'
                    + 'RAWSPEEDBMP' + str(speed_int[0]) + '_' + str(speed_int[1]) + '.csv'
                    , index = True, header=True)
    print("####### new_stat again ######")
    print(new_stat[['file name', 'depth', 'Rpm', 'wv_x']])
    cols_plot = ['depth', 'Rpm', 'wv_x']
    new_stat[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)

else: 
    print('couldn\'t find images for Rpm between {0} and {1}'.format(str(speed_int[0]), str(speed_int[1])))
# Out:
# ####### stat_comb ######
#                                     index  equivalent_diameter  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00   641427             7.653040
# 2020-04-23 11:18:51.909500+00:00   990164            10.092530
# 2020-04-23 13:18:25.448647+00:00  1497213             5.292567
#
#                                                   export name  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00  D20200423T103327.892945-PN0
# 2020-04-23 11:18:51.909500+00:00  D20200423T111851.909500-PN0
# 2020-04-23 13:18:25.448647+00:00  D20200423T131825.448647-PN0
#
#                                   major_axis_length    maxc   maxr    minc  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00           8.937106  2135.0   79.0  2127.0
# 2020-04-23 11:18:51.909500+00:00          16.590473  2052.0   85.0  2044.0
# 2020-04-23 13:18:25.448647+00:00           6.460729   349.0  115.0   342.0
#
#                                   minor_axis_length   minr  particle index  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00           6.888223   69.0               0
# 2020-04-23 11:18:51.909500+00:00           6.709040   68.0               0
# 2020-04-23 13:18:25.448647+00:00           4.873047  110.0               0
#
#                                    ...        Rpm  Salinity  Temperature  \
# timestamp                          ...
# 2020-04-23 10:33:27.892945+00:00   ...     1131.0    32.128        6.004
# 2020-04-23 11:18:51.909500+00:00   ...     1405.0    27.186        6.872
# 2020-04-23 13:18:25.448647+00:00   ...        NaN       NaN          NaN
#
#                                   Turbidity  WaterDensity      wv_x      wv_y  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00    557.143      1025.341  1.300044 -0.038630
# 2020-04-23 11:18:51.909500+00:00    428.571      1021.298  1.528275 -0.022324
# 2020-04-23 13:18:25.448647+00:00        NaN           NaN       NaN       NaN
#
#                                       wv_z                file name  partind
# timestamp
# 2020-04-23 10:33:27.892945+00:00 -0.081150  D20200423T103327.892945      PN0
# 2020-04-23 11:18:51.909500+00:00 -0.108958  D20200423T111851.909500      PN0
# 2020-04-23 13:18:25.448647+00:00       NaN  D20200423T131825.448647      PN0
#
# [3 rows x 55 columns]
# ####### new_stat ######
# <bound method NDFrame.head of                                     index  equivalent_diameter  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00   641427             7.653040
# 2020-04-23 11:18:51.909500+00:00   990164            10.092530
# 2020-04-23 13:18:25.448647+00:00  1497213             5.292567
#
#                                                   export name  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00  D20200423T103327.892945-PN0
# 2020-04-23 11:18:51.909500+00:00  D20200423T111851.909500-PN0
# 2020-04-23 13:18:25.448647+00:00  D20200423T131825.448647-PN0
#
#                                   major_axis_length    maxc   maxr    minc  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00           8.937106  2135.0   79.0  2127.0
# 2020-04-23 11:18:51.909500+00:00          16.590473  2052.0   85.0  2044.0
# 2020-04-23 13:18:25.448647+00:00           6.460729   349.0  115.0   342.0
#
#                                   minor_axis_length   minr  particle index  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00           6.888223   69.0               0
# 2020-04-23 11:18:51.909500+00:00           6.709040   68.0               0
# 2020-04-23 13:18:25.448647+00:00           4.873047  110.0               0
#
#                                    ...        Rpm  Salinity  Temperature  \
# timestamp                          ...
# 2020-04-23 10:33:27.892945+00:00   ...     1131.0    32.128        6.004
# 2020-04-23 11:18:51.909500+00:00   ...     1405.0    27.186        6.872
# 2020-04-23 13:18:25.448647+00:00   ...        NaN       NaN          NaN
#
#                                   Turbidity  WaterDensity      wv_x      wv_y  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00    557.143      1025.341  1.300044 -0.038630
# 2020-04-23 11:18:51.909500+00:00    428.571      1021.298  1.528275 -0.022324
# 2020-04-23 13:18:25.448647+00:00        NaN           NaN       NaN       NaN
#
#                                       wv_z                file name  partind
# timestamp
# 2020-04-23 10:33:27.892945+00:00 -0.081150  D20200423T103327.892945      PN0
# 2020-04-23 11:18:51.909500+00:00 -0.108958  D20200423T111851.909500      PN0
# 2020-04-23 13:18:25.448647+00:00       NaN  D20200423T131825.448647      PN0
#
# [3 rows x 55 columns]>
# Index(['index', 'equivalent_diameter', 'export name', 'major_axis_length',
#        'maxc', 'maxr', 'minc', 'minor_axis_length', 'minr', 'particle index',
#        'probability_bubble', 'probability_copepod', 'probability_diatom_chain',
#        'probability_faecal_pellets', 'probability_oil', 'probability_oily_gas',
#        'probability_other', 'saturation', 'solidity', 'highest prob',
#        'AirSaturation', 'Chlorophyll', 'Conductivity', 'DissolvedOxygen',
#        'lat', 'lon', 'height', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'u', 'v',
#        'w', 'vx', 'vy', 'vz', 'p', 'q', 'r', 'depth', 'alt', 'Pressure', 'Rpm',
#        'Salinity', 'Temperature', 'Turbidity', 'WaterDensity', 'wv_x', 'wv_y',
#        'wv_z', 'file name', 'partind'],
#       dtype='object')
# Creation of the directory F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/RawSpeeds030_10000 failed
# conversion completed!
# ####### new_stat again ######
#                                                 file name   depth     Rpm  \
# timestamp
# 2020-04-23 10:33:27.892945+00:00  D20200423T103327.892945  12.083  1131.0
# 2020-04-23 11:18:51.909500+00:00  D20200423T111851.909500   2.661  1405.0
# 2020-04-23 13:18:25.448647+00:00  D20200423T131825.448647     NaN     NaN
#
#                                       wv_x
# timestamp
# 2020-04-23 10:33:27.892945+00:00  1.300044
# 2020-04-23 11:18:51.909500+00:00  1.528275
# 2020-04-23 13:18:25.448647+00:00       NaN

# %%
RAWSPEEDBMP = "F:/AILARON/Fieldwork/2020-04-AlgaeBloom/lauv-roald/2020-04-23/RawSpeeds"
speed_int = [0, 3000]
new_stat = get_raw_speed(stat_comb, scenes, speed_int, RAWDIR, RAWSPEEDBMP)

if len(new_stat) > 0:
    silc_to_bmp(new_stat['file name'].tolist(), RAWDIR, RAWSPEEDBMP + str(speed_int[0]) + '_' + str(speed_int[1]))
    new_stat.to_csv(RAWSPEEDBMP + str(speed_int[0]) + '_' + str(speed_int[1]) 
                    + '/'
                    + 'RAWSPEEDBMP' + str(speed_int[0]) + '_' + str(speed_int[1]) + '.csv'
                    , index = False, header=True)
else: 
    print('couldn\'t find images for Rpm between {0} and {1}'.format(str(speed_int[0]), str(speed_int[1])))

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
mp = ax.scatter3D(df['x'],df['y'],df['depth'], c=df['WaterDensity'], cmap=cmocean.cm.dense) # ,norm = colors.LogNorm()
ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
ax.set_xlabel('longitude', fontsize=12, labelpad=-15)
ax.set_ylabel('latitude', fontsize=12, labelpad=-13)
ax.zaxis.set_rotate_label(False) 
x_lab_pos, y_lab_pos = ax.zaxis.label.get_position()
print('x_lab_pos', x_lab_pos, 'y_lab_pos', y_lab_pos)
ax.zaxis._autolabelpos=False
ax.zaxis.label.set_position([x_lab_pos,-10])
#ax.set_zlabel('Depth (meter)', rotation=100, fontsize=12)
#ax.set_zlabel('Depth (meter)', rotation=96, fontsize=10)
ax.set_zlabel('Depth (meter)', rotation=95, fontsize=12)
ax.set_zlabel('Depth (meter)', fontsize=10)
ax.dist = 0
cb = fig.colorbar(mp)

cb.ax.set_ylabel('Density (kg/m\u00b3)', fontsize=14)

print(df['WaterDensity'].min(), df['WaterDensity'].max())
cb.ax.get_yaxis().set_ticks(np.arange(int(df['WaterDensity'].min()), 
                                      int(df['WaterDensity'].max()+1), step=2))
cb.ax.invert_yaxis()
ax.xaxis._axinfo["grid"].update({"linewidth":0.2, "color" : "#D3D3D3"})
ax.yaxis._axinfo["grid"].update({"linewidth":0.2, "color" : "#D3D3D3"})
ax.zaxis._axinfo["grid"].update({"linewidth":0.2, "color" : "#D3D3D3"})
#ax.view_init(75, 269)
#ax.view_init(60, 260)
#ax.view_init(50, 260)
ax.view_init(30, 30)
plt.gca().invert_zaxis() 
plt.show()
# Out:
# x_lab_pos 0.5 y_lab_pos 0
# 999.914 1025.806

# %%
# -*- coding : utf-8 -*-
local_encoding = 'cp850'  # adapt for other encodings
### SALINITY 
fig = plt.figure(figsize=(7,7))
request = cimgt.StamenTerrain()
ax = plt.subplot(111, projection=request.crs)
plt.sca(ax) 
mp = map_plot(df, request, 'Salinity', cmocean.cm.haline)
cb = fig.colorbar(mp)
cb.ax.set_ylabel('Practical Salinity Unit (PSU)', fontsize=20)
plt.show()
fig.savefig(OUTPUTDIR + '/' + 'mapplot_salinity.eps', bbox_inches='tight')

### TEMPERATURE
fig = plt.figure(figsize=(7,7))
request = cimgt.StamenTerrain()
ax = plt.subplot(111, projection=request.crs)
plt.sca(ax)
mp = map_plot(df, request, 'Temperature', cmocean.cm.ice_r)
cb = fig.colorbar(mp)
cb.ax.set_ylabel('Temperature (\xb0C)', fontsize=20)
plt.show()
fig.savefig(OUTPUTDIR + '/' + 'mapplot_temperature.eps', bbox_inches='tight')

### DENSITY
fig = plt.figure(figsize=(7,7))
request = cimgt.StamenTerrain()
ax = plt.subplot(111, projection=request.crs)
plt.sca(ax) 
mp = map_plot(df, request, 'WaterDensity', cmocean.cm.dense)
cb = fig.colorbar(mp)
cb.ax.set_ylabel('kg/m\u00b3', fontsize=20)
plt.show()
fig.savefig(OUTPUTDIR + '/' + 'mapplot_density.eps', bbox_inches='tight')

# %%
cols_plot = ['Salinity','depth', 'Rpm', 'wv_x']
df[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
print(df[['Salinity','depth', 'Rpm', 'wv_x']].tail())
# Out:
#                                      Salinity  depth  Rpm  wv_x
# timestamp
# 2020-04-21 13:02:55.956000090+00:00       NaN  0.130    0   NaN
# 2020-04-21 13:02:56.956000090+00:00       NaN  0.127    0   NaN
# 2020-04-21 13:02:57.956000090+00:00       NaN  0.128    0   NaN
# 2020-04-21 13:02:58.956000090+00:00       NaN  0.124    0   NaN
# 2020-04-21 13:02:59.956000090+00:00       NaN  0.126    0   NaN
